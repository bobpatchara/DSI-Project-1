# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: SAT&ACT 2017-2019 Data Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# #Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# #**To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# I am working as a data analyst at Niche company which is a market leader in connecting colleges and schools with students and families and helps million of students and families find and enroll in the right school for them. My project is "to help Niche company gaining more brand awareness by collaborating a new project  “University Scholarship” with Global Standardized Test Organization like SAT or ACT, to provide an examination fee  and give a free education consulting to  scholarship students"
#
# Project objectives:
# - To analyze the SAT and ACT Tests taken in 2017, 2018 and 2019
# - To analyze the trend of aggregated scores and participation rates for each state in United States.
# - To provide recommendations to Data Analytic of Niche team and marketing team whether or not to choose collaborating with SAT or ACT  to help them improve participation rates for future tests and also increase both brand awarenesses

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %%
#Necessary outside research

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# #### My Datasets with a brief description:
# - act_2017.csv: 2017 ACT Scores by State
# - act_2018.csv: 2018 ACT Scores by State
# - act_2019.csv: 2019 ACT Scores by State
# - sat_2017.csv: 2017 SAT Scores by State
# - sat_2018.csv: 2018 SAT Scores by State
# - sat_2019.csv: 2019 SAT Scores by State

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def cal_mean(numbers):
    return float(sum(numbers)) / max(len(numbers), 1)

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def std_dev(some_list):
    mean_sum = 0
    for num in some_list: 
        mean_sum += num
    mean_list = mean_sum/len(some_list)
    
    var_sum = 0
    for num in some_list: 
        var_sum += ((num - mean_list) ** 2)
    std_list = (var_sum * (1/len(some_list))) ** (1/2)
    
    return std_list

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def remove_percent_symbol(dataframe):
    dataframe['Participation'] = dataframe['Participation'].apply(lambda x: float(x.replace('%',''))/100)
    return dataframe

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# import libraries

# maths
import scipy.stats as stats
import numpy as np
import pandas as pd
from pandas.api.types import is_numeric_dtype

# visual
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

#warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ### 2017 Data Import & Cleaning

# %% [markdown]
# ### 1. Import SAT & ACT 2017 Data

# %%
# import 2017 data

df_sat_2017 = pd.read_csv('../data/sat_2017.csv')
df_act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# ### 2a. Display Data: SAT 2017

# %%
df_sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %% [markdown]
# ### 2b. Display Data: ACT 2017

# %%
df_act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# ### 3. Data types

# %%
# SAT 2017 Data Types

df_sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# ACT 2017 Data Types

df_act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# ### 4a. Identifying the errors in the SAT & ACT 2017 Dataset

# %% [markdown]
# After keep looking for the unusual dataset, both in the sat 2017 & act 2017, Participation columns are displayed as a percentage but processing as strings. In act 2017, for the ' Composite' score should be a float, but it is processing as an object.

# %% [markdown]
# ### 4b. Create a function that will turn incorrect datatypes in SAT 2017 Data

# %%
#Convert percentage strings to floats

def str_to_float(df, col_name):
    df[col_name] = df[col_name].map(lambda parti_rate : parti_rate.replace('%', ' ')) #remove percentage sign(%)
    df[col_name] = df[col_name].astype(float)                                                         #conver str to float
    df[col_name] = df[col_name].map(lambda parti_rate: parti_rate/100)                 #divide number by 100
    print(df[col_name].dtypes)                                                                                #print column dtype to ensure the change has already made
    return(df[col_name].head())                                                                            #return column head for checking data

# %%
#calling function to change data type from str_to_float
str_to_float(df_sat_2017, 'Participation')
# Out:
# float64
# 0    0.05
# 1    0.38
# 2    0.30
# 3    0.03
# 4    0.53
# Name: Participation, dtype: float64

# %% [markdown]
# ### 4c. Create a function that will turn incorrect datatypes in ACT 2017 Data

# %%
#calling function to change data type from str_to_float
str_to_float(df_act_2017, 'Participation')
# Out:
# float64
# 0    0.60
# 1    1.00
# 2    0.65
# 3    0.62
# 4    1.00
# Name: Participation, dtype: float64

# %%
#act_2017 composite scores are strings because one value contains a letter: "20.2x"

#Remove  'X'
df_act_2017['Composite'] = df_act_2017['Composite'].map(lambda composite_score : composite_score.replace('x', ' '))

#Convert column to floats
df_act_2017['Composite'] = df_act_2017['Composite'].astype(float)

# %%
df_act_2017['Composite'].dtypes
# Out:
# dtype('float64')

# %%
df_act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# ### 4d. Checking Min and Max to ensure all values are withing range

# %% [markdown]
# Checking the Min/Max Values in SAT 2017: The range of scores for the SAT Math and Evidence Reading and Writing sections is 200-800 scores

# %%
#Minimum values in the sat_2017 dataset.
print(df_sat_2017.min())
# Out:
# State                                 Alabama
# Participation                            0.02
# Evidence-Based Reading and Writing        482
# Math                                       52
# Total                                     950
# dtype: object

# %%
#Maximum values in the sat_2017 dataset.
print(df_sat_2017.max())
# Out:
# State                                 Wyoming
# Participation                             1.0
# Evidence-Based Reading and Writing        644
# Math                                      651
# Total                                    1295
# dtype: object

# %% [markdown]
# After reviewing the min and max for the sat_2017 dataset, there apprears to be an error:
#     The minimum value for "Math" is 52, which is below the minimum value in the range 200-800

# %%
#Checking the incorrect data by using .head(10) too see any issues
df_sat_2017.sort_values(['Math']).head(10)
# Out:
#                    State  Participation  Evidence-Based Reading and Writing  \
# 20              Maryland           0.69                                 536
# 8   District of Columbia           1.00                                 482
# 7               Delaware           1.00                                 503
# 12                 Idaho           0.93                                 513
# 22              Michigan           1.00                                 509
# 9                Florida           0.83                                 520
# 19                 Maine           0.95                                 513
# 43                 Texas           0.62                                 513
# 6            Connecticut           1.00                                 530
# 10               Georgia           0.61                                 535
#
#     Math  Total
# 20    52   1060
# 8    468    950
# 7    492    996
# 12   493   1005
# 22   495   1005
# 9    497   1017
# ...

# %%
#Sorting the data columns 'Math'  and need to be changed by subtracting score from the total to find the real value of Math, which is 524.
df_sat_2017.sort_values(['Math']).head(1)
# Out:
#        State  Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           0.69                                 536    52   1060

# %%
#Find the new row and column where the number needs to change and assign new number
df_sat_2017.loc[20, 'Math'] = 524

# %%
#check to see if the number was replaced
df_sat_2017['Math'][20]
# Out:
# 524

# %%
#Selecting row [20] to check for correct data
df_sat_2017.loc[df_sat_2017['State'] == 'Maryland']
# Out:
#        State  Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           0.69                                 536   524   1060

# %% [markdown]
# Checking the Min/Max Values in ACT 2017: The range of scores for the ACT for all categories  is 1-36.

# %%
#Minimum values in the act_2017 dataset.
print(df_act_2017.min())
# Out:
# State            Alabama
# Participation       0.08
# English             16.3
# Math                18.0
# Reading             18.1
# Science              2.3
# Composite           17.8
# dtype: object

# %%
#Maximum values in the act_2017 dataset.
print(df_act_2017.max())
# Out:
# State            Wyoming
# Participation        1.0
# English             25.5
# Math                25.3
# Reading             26.0
# Science             24.9
# Composite           25.5
# dtype: object

# %% [markdown]
# The minimum and maximum values in the ACT 2017 dataset appear to be within range

# %% [markdown]
# ### 4e. Checking that the number of rows in each dataset are aligned

# %% [markdown]
# There is one extra row in ACT.

# %%
#The 52 rows in act_2017 are attributed to all 50 US states, the District of Columbia, and 'National'
df_act_2017_row, act_2017_column = df_act_2017.shape
print("Number of rows in ACT 2017: {}.".format(df_act_2017_row))
# Out:
# Number of rows in ACT 2017: 52.

# %%
df_act_2017['State'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                 National
# 1                  Alabama
# 2                   Alaska
# 3                  Arizona
# 4                 Arkansas
# 5               California
# 6                 Colorado
# 7              Connecticut
# 8                 Delaware
# 9     District of Columbia
# 10                 Florida
# 11                 Georgia
# 12                  Hawaii
# 13                   Idaho
# 14                Illinois
# 15                 Indiana
# 16                    Iowa
# 17                  Kansas
# 18                Kentucky
# 19               Louisiana
# 20                   Maine
# 21                Maryland
# 22           Massachusetts
# 23                Michigan
# 24               Minnesota
# 25             Mississippi
# 26                Missouri
# 27                 Montana
# 28                Nebraska
# 29                  Nevada
# 30           New Hampshire
# 31              New Jersey
# ...

# %%
#The 51 rows in sat_2017 are attributed to all 50 US states and the District of Columbia
df_sat_2017_row, sat_2017_column = df_sat_2017.shape
print("Number of rows in SAT 2017: {}.".format(df_sat_2017_row))
# Out:
# Number of rows in SAT 2017: 51.

# %%
df_sat_2017['State'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# ...

# %%
#Remove the 'National' row in ACT 2017 dataset, which is in th 0th row.
df_act_2017.drop(index = 0, inplace = True)

# %%
#Ensure that ACT 2017 has 51 rows after remove the 'National row
df_act_2017.shape
# Out:
# (51, 7)

# %%
check_equal_lists = np.array_equal(np.array(df_sat_2017['state']).sort(), np.array(df_act_2017['state']).sort())
result
# Out:
# True

# %% [markdown]
# ### 5. Pre-screening the data after fixed the error

# %%
#checking the first 10 rows of the SAT 2017 Dataset
df_sat_2017.head(10)
# Out:
#                   State  Participation  Evidence-Based Reading and Writing  \
# 0               Alabama           0.05                                 593
# 1                Alaska           0.38                                 547
# 2               Arizona           0.30                                 563
# 3              Arkansas           0.03                                 614
# 4            California           0.53                                 531
# 5              Colorado           0.11                                 606
# 6           Connecticut           1.00                                 530
# 7              Delaware           1.00                                 503
# 8  District of Columbia           1.00                                 482
# 9               Florida           0.83                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# ...

# %%
#checking the first 10 rows of the ACT 2017 Dataset
df_act_2017.head(10)
# Out:
#                    State  Participation  English  Math  Reading  Science  \
# 1                Alabama           1.00     18.9  18.4     19.7     19.4
# 2                 Alaska           0.65     18.7  19.8     20.4     19.9
# 3                Arizona           0.62     18.6  19.8     20.1     19.8
# 4               Arkansas           1.00     18.9  19.0     19.7     19.5
# 5             California           0.31     22.5  22.7     23.1     22.2
# 6               Colorado           1.00     20.1  20.3     21.2     20.9
# 7            Connecticut           0.31     25.5  24.6     25.6     24.6
# 8               Delaware           0.18     24.1  23.4     24.8     23.6
# 9   District of Columbia           0.32     24.4  23.5     24.9     23.5
# 10               Florida           0.73     19.0  19.4     21.0     19.4
#
#     Composite
# 1        19.2
# 2        19.8
# 3        19.7
# 4        19.4
# 5        22.8
# 6        20.8
# 7        25.2
# 8        24.1
# 9        24.2
# ...

# %% [markdown]
# ### 6. Renaming Columns for more expressive name to see the difference between SAT and ACT Columns

# %% [markdown]
# ### 2017 SAT Column Renaming

# %%
#List Dictionary for changing name,  specifying test type and year.

new_col_sat_17 = {'State': 'state',
                        'Participation': 'sat_participation_17',
                        'Evidence-Based Reading and Writing' : 'sat_reading_and_writing_17',
                        'Math': 'sat_math_17',
                        'Total': 'sat_total_17'}
df_sat_2017.rename(columns = new_col_sat_17, inplace = True)

# %%
#Checking the new columns to make sure all changes already been done
df_sat_2017.columns
# Out:
# Index(['state', 'sat_participation_17', 'sat_reading_and_writing_17',
#        'sat_math_17', 'sat_total_17'],
#       dtype='object')

# %%
df_sat_2017.head(51)
# Out:
#                    state  sat_participation_17  sat_reading_and_writing_17  \
# 0                Alabama                  0.05                         593
# 1                 Alaska                  0.38                         547
# 2                Arizona                  0.30                         563
# 3               Arkansas                  0.03                         614
# 4             California                  0.53                         531
# 5               Colorado                  0.11                         606
# 6            Connecticut                  1.00                         530
# 7               Delaware                  1.00                         503
# 8   District of Columbia                  1.00                         482
# 9                Florida                  0.83                         520
# 10               Georgia                  0.61                         535
# ...

# %% [markdown]
# ### 2017 ACT Column Renaming

# %%
#List Dictionary for changing name,  specifying test type and year.

new_col_act_17 = {'State': 'state',
                        'Participation': 'act_participation_17',
                        'English' : 'act_english_17',
                        'Math': 'act_math_17',
                        'Reading' : 'act_reading_17',
                        'Science' : 'act_science_17',
                        'Composite': 'act_composite_17'}
df_act_2017.rename(columns = new_col_act_17, inplace = True)

# %%
#Checking the new columns to make sure all changes already been done
df_act_2017.columns
# Out:
# Index(['state', 'act_participation_17', 'act_english_17', 'act_math_17',
#        'act_reading_17', 'act_science_17', 'act_composite_17'],
#       dtype='object')

# %%
df_act_2017.head(51)
# Out:
#                    state  act_participation_17  act_english_17  act_math_17  \
# 1                Alabama                  1.00            18.9         18.4
# 2                 Alaska                  0.65            18.7         19.8
# 3                Arizona                  0.62            18.6         19.8
# 4               Arkansas                  1.00            18.9         19.0
# 5             California                  0.31            22.5         22.7
# 6               Colorado                  1.00            20.1         20.3
# 7            Connecticut                  0.31            25.5         24.6
# 8               Delaware                  0.18            24.1         23.4
# 9   District of Columbia                  0.32            24.4         23.5
# 10               Florida                  0.73            19.0         19.4
# 11               Georgia                  0.55            21.0         20.9
# ...

# %%
#Checking the equal value of  2 lists of  ACT and SAT 2018 State column
sat_2017_list = list(df_sat_2017['state'])
act_2017_list = list(df_act_2017['state'])

# %%
set(sat_2017_list).difference(act_2017_list) #Missing value in second list
# Out:
# set()

# %%
set(act_2017_list).difference(sat_2017_list) #Missing value in second list
# Out:
# set()

# %%
def check_if_equal(list_1, list_2):
    """ Check if both the lists are of same length and if yes then compare
    sorted versions of both the list to check if both of them are equal
    i.e. contain similar elements with same frequency. """
    if len(list_1) != len(list_2):
        return False
    return sorted(list_1) == sorted(list_2)

# %%
#Lists are not equal and not contain similar elements with the same frequency
if check_if_equal(df_sat_2017['state'], df_act_2017['state']):
    print('Lists are equal and also contain similar elements with same frequency')
else:
    print('Lists are not equal')
# Out:
# Lists are equal and also contain similar elements with same frequency

# %%
#There is no the existence of NaN values under the ACT_2017 DataFrame Columns 
df_act_2017.isnull().values.any()
# Out:
# False

# %%
#There is no the existence of NaN values under the SAT_2017 DataFrame Columns 
df_sat_2017.isnull().values.any()
# Out:
# False

# %%
df_sat_2017.loc[df_sat_2017['state'] == 'National'].index.values #No 'National' in DataFrame
# Out:
# array([], dtype=int64)

# %%
df_act_2017.loc[df_act_2017['state'] == 'National'].index.values #No 'National' in DataFrame
# Out:
# array([], dtype=int64)

# %% [markdown]
# ### 7. Merging SAT & ACT 2017 DataFrame

# %% [markdown]
# Join the SAT & ACT 2017 dataframes using the state as the key value by assigned a new variable as sat_act_2017_csv

# %%
#Assign a new variable for concatenating SAT & ACT 2017 DataFrames

sat_act_2017_csv = pd.merge(df_sat_2017, df_act_2017, on='state')

# %%
#Checking after merged dataset
print(sat_act_2017_csv.shape)
sat_act_2017_csv.head(51)
# Out:
# (51, 11)
#                    state  sat_participation_17  sat_reading_and_writing_17  \
# 0                Alabama                  0.05                         593
# 1                 Alaska                  0.38                         547
# 2                Arizona                  0.30                         563
# 3               Arkansas                  0.03                         614
# 4             California                  0.53                         531
# 5               Colorado                  0.11                         606
# 6            Connecticut                  1.00                         530
# 7               Delaware                  1.00                         503
# 8   District of Columbia                  1.00                         482
# 9                Florida                  0.83                         520
# 10               Georgia                  0.61                         535
# ...

# %% [markdown]
# ### 8. Create new file of SAT&aCT 2017

# %%
#Create file for sat_act_2017.csv file
sat_act_2017_csv.to_csv('../data/sat_act_2017_csv.csv')

# %% [markdown]
# ### 2018 Data Import & Cleaning

# %%
# import 2017 data

df_sat_2018 = pd.read_csv('../data/sat_2018.csv')
df_act_2018 = pd.read_csv('../data/act_2018.csv')

# %%
df_sat_2018.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            6%                                 595
# 1                Alaska           43%                                 562
# 2               Arizona           29%                                 577
# 3              Arkansas            5%                                 592
# 4            California           60%                                 540
# 5              Colorado          100%                                 519
# 6           Connecticut          100%                                 535
# 7              Delaware          100%                                 505
# 8  District of Columbia           92%                                 497
# 9               Florida           56%                                 550
#
#    Math  Total
# 0   571   1166
# 1   544   1106
# 2   572   1149
# 3   576   1169
# 4   536   1076
# 5   506   1025
# 6   519   1053
# 7   492    998
# ...

# %%
df_sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
df_sat_2018.shape
# Out:
# (51, 5)

# %%
df_act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
df_act_2018.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
df_act_2018.shape
# Out:
# (52, 3)

# %%
str_to_float(df_sat_2018, 'Participation')
# Out:
# float64
# 0    0.06
# 1    0.43
# 2    0.29
# 3    0.05
# 4    0.60
# Name: Participation, dtype: float64

# %%
df_sat_2018.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
str_to_float(df_act_2018, 'Participation')
# Out:
# float64
# 0    1.00
# 1    0.33
# 2    0.66
# 3    1.00
# 4    0.27
# Name: Participation, dtype: float64

# %%
df_act_2018.dtypes
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %% [markdown]
# ### Checking Minimun and Maximum of SAT Scores to ensure that all values are within range.

# %%
df_sat_2018.min()
# Out:
# State                                 Alabama
# Participation                            0.02
# Evidence-Based Reading and Writing        480
# Math                                      480
# Total                                     977
# dtype: object

# %%
df_sat_2018.max()
# Out:
# State                                 Wyoming
# Participation                             1.0
# Evidence-Based Reading and Writing        643
# Math                                      655
# Total                                    1298
# dtype: object

# %% [markdown]
# ### Checking Minimun and Maximum of ACT Scores to ensure that all values are within range.

# %%
df_act_2018.min()
# Out:
# State            Alabama
# Participation       0.07
# Composite           17.7
# dtype: object

# %%
df_act_2018.max()
# Out:
# State            Wyoming
# Participation        1.0
# Composite           25.6
# dtype: object

# %% [markdown]
# It seems that 2018 Dataset of ACT and SAT appear to be within their score ranges

# %% [markdown]
# ### Checking the number of rows and NaN Value in SAT and ACT 2018 Dataset are aligned

# %%
df_act_2018_row, df_act_2018_col = df_act_2018.shape
print("The number of rows in ACT 2018: {} ".format(df_act_2018_row))
print(list(df_act_2018['State'].sort_values()))
# Out:
# The number of rows in ACT 2018: 52
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']

# %%
#There is no the existence of NaN values under the ACT_2018 DataFrame Columns 
df_act_2018.isnull().values.any()
# Out:
# False

# %%
#Find the duplicate row, Maine State in index 19,20
df_act_2018.head(51)
# Out:
#                    State  Participation  Composite
# 0                Alabama           1.00       19.1
# 1                 Alaska           0.33       20.8
# 2                Arizona           0.66       19.2
# 3               Arkansas           1.00       19.4
# 4             California           0.27       22.7
# 5               Colorado           0.30       23.9
# 6            Connecticut           0.26       25.6
# 7               Delaware           0.17       23.8
# 8   District of columbia           0.32       23.6
# 9                Florida           0.66       19.9
# 10               Georgia           0.53       21.4
# 11                Hawaii           0.89       18.9
# 12                 Idaho           0.36       22.3
# 13              Illinois           0.43       23.9
# 14               Indiana           0.32       22.5
# 15                  Iowa           0.68       21.8
# 16                Kansas           0.71       21.6
# ...

# %%
#drop the duplicate row of Maine State.
df_act_2018.drop(index = 19, inplace = True)

# %%
df_act_2018_row, df_act_2018_col = df_act_2018.shape
print("The number of rows in ACT 2018: {} ".format(df_act_2018_row))
print(list(df_act_2018['State'].sort_values()))
# Out:
# The number of rows in ACT 2018: 51
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']

# %%
#There is no the existence of NaN values under the SAT_2018 DataFrame Columns 
df_sat_2018.isnull().values.any()
# Out:
# False

# %%
df_sat_2018.shape
# Out:
# (51, 5)

# %%
df_sat_2018_row, df_sat_2018_col = df_sat_2018.shape
print("The number of rows in SAT 2018: {} ".format(df_sat_2018_row))
print(list(df_sat_2018['State'].sort_values()))
# Out:
# The number of rows in SAT 2018: 51
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']

# %%
df_sat_2018.loc[df_sat_2018['State'] == 'National'].index.values
# Out:
# array([], dtype=int64)

# %% [markdown]
# ### Checking the errors of ACT and SAT States column which contain the same element or not?

# %%
def check_if_equal(list_1, list_2):
    """ Check if both the lists are of same length and if yes then compare
    sorted versions of both the list to check if both of them are equal
    i.e. contain similar elements with same frequency. """
    if len(list_1) != len(list_2):
        return False
    return sorted(list_1) == sorted(list_2)

# %%
#Lists are not equal and not contain similar elements with the same frequency
if check_if_equal(df_sat_2018['State'], df_act_2018['State']):
    print('Lists are equal and also contain similar elements with same frequency')
else:
    print('Lists are not equal')
# Out:
# Lists are not equal

# %% [markdown]
# ### Finding the errors values of State column between SAT and ACT 2018

# %%
#Checking the equal value of  2 lists of  ACT and SAT 2018 State column
sat_2018_list = list(df_sat_2018['State'])
act_2018_list = list(df_act_2018['State'])

# %%
(set(sat_2018_list).difference(act_2018_list)) #Missing value in second list
# Out:
# {'District of Columbia'}

# %%
(set(act_2018_list).difference(sat_2018_list)) #Missing value in firs list
# Out:
# {'District of columbia'}

# %% [markdown]
# ### Fixed the spelling mistakes in SAT and ACT 2018

# %%
df_act_2018.head(10)
# Out:
#                   State  Participation  Composite
# 0               Alabama           1.00       19.1
# 1                Alaska           0.33       20.8
# 2               Arizona           0.66       19.2
# 3              Arkansas           1.00       19.4
# 4            California           0.27       22.7
# 5              Colorado           0.30       23.9
# 6           Connecticut           0.26       25.6
# 7              Delaware           0.17       23.8
# 8  District of columbia           0.32       23.6
# 9               Florida           0.66       19.9

# %%
#Select the row and column where the letter needs to be changed nad assign the correct spellings.
df_act_2018.loc[8, 'State'] = 'District of Columbia'

# %%
#Selecting row [20] to check for correct data
df_act_2018.loc[df_act_2018['State'] == 'District of Columbia']
# Out:
#                   State  Participation  Composite
# 8  District of Columbia           0.32       23.6

# %%
#Lists are  equal and  contain similar elements with the same frequency
if check_if_equal(df_sat_2018['State'], df_act_2018['State']):
    print('Lists are equal and also contain similar elements with same frequency')
else:
    print('Lists are not equal')
# Out:
# Lists are equal and also contain similar elements with same frequency

# %% [markdown]
# ### Preview a new data after fixed changes

# %%
df_act_2018.head(10)
# Out:
#                   State  Participation  Composite
# 0               Alabama           1.00       19.1
# 1                Alaska           0.33       20.8
# 2               Arizona           0.66       19.2
# 3              Arkansas           1.00       19.4
# 4            California           0.27       22.7
# 5              Colorado           0.30       23.9
# 6           Connecticut           0.26       25.6
# 7              Delaware           0.17       23.8
# 8  District of Columbia           0.32       23.6
# 9               Florida           0.66       19.9

# %%
df_sat_2018.head(10)
# Out:
#                   State  Participation  Evidence-Based Reading and Writing  \
# 0               Alabama           0.06                                 595
# 1                Alaska           0.43                                 562
# 2               Arizona           0.29                                 577
# 3              Arkansas           0.05                                 592
# 4            California           0.60                                 540
# 5              Colorado           1.00                                 519
# 6           Connecticut           1.00                                 535
# 7              Delaware           1.00                                 505
# 8  District of Columbia           0.92                                 497
# 9               Florida           0.56                                 550
#
#    Math  Total
# 0   571   1166
# 1   544   1106
# 2   572   1149
# 3   576   1169
# 4   536   1076
# 5   506   1025
# 6   519   1053
# ...

# %% [markdown]
# ### Rename Columns' name of SAT & ACT 2018

# %%
#SAT 2018 Column Renaming
df_sat_2018.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
#List Dictionary for changing name,  specifying test type and year.

new_col_sat_18 = {'State': 'state',
                        'Participation': 'sat_participation_18',
                        'Evidence-Based Reading and Writing' : 'sat_reading_and_writing_18',
                        'Math': 'sat_math_18',
                        'Total': 'sat_total_18'}
df_sat_2018.rename(columns = new_col_sat_18, inplace = True)

# %%
#SAT 2018 Column after renaming
df_sat_2018.columns
# Out:
# Index(['state', 'sat_participation_18', 'sat_reading_and_writing_18',
#        'sat_math_18', 'sat_total_18'],
#       dtype='object')

# %%
df_sat_2018.head()
# Out:
#         state  sat_participation_18  sat_reading_and_writing_18  sat_math_18  \
# 0     Alabama                  0.06                         595          571
# 1      Alaska                  0.43                         562          544
# 2     Arizona                  0.29                         577          572
# 3    Arkansas                  0.05                         592          576
# 4  California                  0.60                         540          536
#
#    sat_total_18
# 0          1166
# 1          1106
# 2          1149
# 3          1169
# 4          1076

# %%
#ACT 2018 Column Renaming
df_act_2018.columns
# Out:
# Index(['State', 'Participation', 'Composite'], dtype='object')

# %%
#List Dictionary for changing name,  specifying test type and year.

new_col_act_18 = {'State': 'state',
                        'Participation': 'act_participation_18',
                        'Composite': 'act_composite_18'}
df_act_2018.rename(columns = new_col_act_18, inplace = True)

# %%
#ACT 2018 Column after renaming
df_act_2018.columns
# Out:
# Index(['state', 'act_participation_18', 'act_composite_18'], dtype='object')

# %%
df_act_2018.head()
# Out:
#         state  act_participation_18  act_composite_18
# 0     Alabama                  1.00              19.1
# 1      Alaska                  0.33              20.8
# 2     Arizona                  0.66              19.2
# 3    Arkansas                  1.00              19.4
# 4  California                  0.27              22.7

# %% [markdown]
# ### Creating SAT & ACT 2018 CSV file and Merged SAT_ACT_2017_To_2018 for creating new DataFrame

# %%
#Assigning a new variable for concatenating SAT & ACT 2018 DataFrame
sat_act_2018_csv = pd.merge(df_sat_2018, df_act_2018, on = 'state')

# %%
#Create sat_act_2018_csv as csv file in data folder
sat_act_2018_csv.to_csv('../data/sat_act_2018_csv.csv')

# %%
sat_act_2018_csv.shape
# Out:
# (51, 7)

# %%
#preview sat_act_2018
sat_act_2018_csv.head()
# Out:
#         state  sat_participation_18  sat_reading_and_writing_18  sat_math_18  \
# 0     Alabama                  0.06                         595          571
# 1      Alaska                  0.43                         562          544
# 2     Arizona                  0.29                         577          572
# 3    Arkansas                  0.05                         592          576
# 4  California                  0.60                         540          536
#
#    sat_total_18  act_participation_18  act_composite_18
# 0          1166                  1.00              19.1
# 1          1106                  0.33              20.8
# 2          1149                  0.66              19.2
# 3          1169                  1.00              19.4
# 4          1076                  0.27              22.7

# %%
#Combined sat_act_2017_csv and sat_act_2018_csv into sat_act_2017_to_2018_csv using the state in each dataframe as the key!
sat_act_2017_to_2018_csv = pd.merge(sat_act_2017_csv, sat_act_2018_csv, on = 'state')

# %%
sat_act_2017_to_2018_csv.head()
# Out:
#         state  sat_participation_17  sat_reading_and_writing_17  sat_math_17  \
# 0     Alabama                  0.05                         593          572
# 1      Alaska                  0.38                         547          533
# 2     Arizona                  0.30                         563          553
# 3    Arkansas                  0.03                         614          594
# 4  California                  0.53                         531          524
#
#    sat_total_17  act_participation_17  act_english_17  act_math_17  \
# 0          1165                  1.00            18.9         18.4
# 1          1080                  0.65            18.7         19.8
# 2          1116                  0.62            18.6         19.8
# 3          1208                  1.00            18.9         19.0
# 4          1055                  0.31            22.5         22.7
#
#    act_reading_17  act_science_17  act_composite_17  sat_participation_18  \
# ...

# %%
#Ensure that there're no errors in the combined files of SAT & ACT 2017-2018 Dataset.
print(sat_act_2017_to_2018_csv.shape)
sat_act_2017_to_2018_csv.info()
# Out:
# (51, 17)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   state                       51 non-null     object
#  1   sat_participation_17        51 non-null     float64
#  2   sat_reading_and_writing_17  51 non-null     int64
#  3   sat_math_17                 51 non-null     int64
#  4   sat_total_17                51 non-null     int64
#  5   act_participation_17        51 non-null     float64
#  6   act_english_17              51 non-null     float64
#  7   act_math_17                 51 non-null     float64
#  8   act_reading_17              51 non-null     float64
#  9   act_science_17              51 non-null     float64
#  10  act_composite_17            51 non-null     float64
#  11  sat_participation_18        51 non-null     float64
#  12  sat_reading_and_writing_18  51 non-null     int64
# ...

# %%
#Create sat_act_2017_to_2018_csv as csv file in data folder
sat_act_2017_to_2018_csv.to_csv('../data/sat_act_2017_to_2018_csv.csv')

# %% [markdown]
# ### Founded another file name 'act_2018_updated.csv' which are provided the score data of science, eng, and math.

# %%
#So, needed to import 'act_2018_updated.csv' for cleaning and add on sat_act_2017_to_2018_csv.
df_act_2018_updated = pd.read_csv('../data/act_2018_updated.csv')

# %%
df_act_2018_updated.head()
# Out:
#         State  Percentage of Students Tested  Average Composite Score  \
# 0     Alabama                            100                     19.1
# 1      Alaska                             33                     20.8
# 2     Arizona                             66                     19.2
# 3    Arkansas                            100                     19.4
# 4  California                             27                     22.7
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
# 2                   18.2                19.4                   19.5
# 3                   19.1                18.9                   19.7
# 4                   22.5                22.5                   23.0
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# 2                   19.2
# 3                   19.4
# ...

# %%
df_act_2018_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          51 non-null     object
#  1   Percentage of Students Tested  51 non-null     int64
#  2   Average Composite Score        51 non-null     float64
#  3   Average English Score          51 non-null     float64
#  4   Average Math Score             51 non-null     float64
#  5   Average Reading Score          51 non-null     float64
#  6   Average Science Score          51 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.7+ KB

# %%
#After checking the row of  the df_act_2018 after cleaning and df_act_2018_updated, they have the same rows, 
#so we need to drop the unncesscary column which is "Average Composite Score", which already is float type and Percentage of Students Tested, which already the same values as df_act_2018

# %%
df_act_2018_updated.columns
# Out:
# Index(['State', 'Percentage of Students Tested', 'Average Composite Score',
#        'Average English Score', 'Average Math Score', 'Average Reading Score',
#        'Average Science Score'],
#       dtype='object')

# %%
df_act_2018_updated.drop(columns = ['Average Composite Score', 'Percentage of Students Tested'], inplace = True)

# %%
df_act_2018_updated.columns
# Out:
# Index(['State', 'Average English Score', 'Average Math Score',
#        'Average Reading Score', 'Average Science Score'],
#       dtype='object')

# %%
df_act_2018_updated.head(51)
# Out:
#                    State  Average English Score  Average Math Score  \
# 0                Alabama                   18.9                18.3
# 1                 Alaska                   19.8                20.6
# 2                Arizona                   18.2                19.4
# 3               Arkansas                   19.1                18.9
# 4             California                   22.5                22.5
# 5               Colorado                   23.9                23.2
# 6            Connecticut                   26.0                24.8
# 7               Delaware                   23.7                23.1
# 8   District of Columbia                   23.7                22.7
# 9                Florida                   19.2                19.3
# 10               Georgia                   20.9                20.7
# 11                Hawaii                   18.2                19.0
# 12                 Idaho                   21.9                21.6
# ...

# %%
#Checking the equal value of  2 lists of  ACT and SAT 2018 State column
sat_act_2017_to_2018_csv_list = list(sat_act_2017_to_2018_csv['state'])
act_2018_updated_list = list(df_act_2018_updated['State'])

# %%
(set(sat_act_2017_to_2018_csv_list).difference(act_2018_updated_list)) #No Missing value in second list
# Out:
# set()

# %%
(set(act_2018_updated_list).difference(sat_act_2017_to_2018_csv_list)) #No Missing value in first list
# Out:
# set()

# %%
#Renaming columns' name of df_act_2018_updated 
new_col_act_18_updated = {'State': 'state',
                        'Average English Score' : 'act_english_18',
                        'Average Math Score': 'act_math_18',
                        'Average Reading Score' : 'act_reading_18',
                        'Average Science Score' : 'act_science_18',}
df_act_2018_updated.rename(columns = new_col_act_18_updated, inplace = True)

# %%
df_act_2018_updated.head()
# Out:
#         state  act_english_18  act_math_18  act_reading_18  act_science_18
# 0     Alabama            18.9         18.3            19.6            19.0
# 1      Alaska            19.8         20.6            21.6            20.7
# 2     Arizona            18.2         19.4            19.5            19.2
# 3    Arkansas            19.1         18.9            19.7            19.4
# 4  California            22.5         22.5            23.0            22.1

# %%
#Combined  df_act_2018_updated with sat_act_2017_to_2018_csv.
sat_act_2017_to_2018_updated_csv = pd.merge(sat_act_2017_to_2018_csv, df_act_2018_updated, on = 'state')

# %%
sat_act_2017_to_2018_updated_csv.head()
# Out:
#         state  sat_participation_17  sat_reading_and_writing_17  sat_math_17  \
# 0     Alabama                  0.05                         593          572
# 1      Alaska                  0.38                         547          533
# 2     Arizona                  0.30                         563          553
# 3    Arkansas                  0.03                         614          594
# 4  California                  0.53                         531          524
#
#    sat_total_17  act_participation_17  act_english_17  act_math_17  \
# 0          1165                  1.00            18.9         18.4
# 1          1080                  0.65            18.7         19.8
# 2          1116                  0.62            18.6         19.8
# 3          1208                  1.00            18.9         19.0
# 4          1055                  0.31            22.5         22.7
#
#    act_reading_17  act_science_17  ...  sat_participation_18  \
# ...

# %%
sat_act_2017_to_2018_updated_csv.columns
# Out:
# Index(['state', 'sat_participation_17', 'sat_reading_and_writing_17',
#        'sat_math_17', 'sat_total_17', 'act_participation_17', 'act_english_17',
#        'act_math_17', 'act_reading_17', 'act_science_17', 'act_composite_17',
#        'sat_participation_18', 'sat_reading_and_writing_18', 'sat_math_18',
#        'sat_total_18', 'act_participation_18', 'act_composite_18',
#        'act_english_18', 'act_math_18', 'act_reading_18', 'act_science_18'],
#       dtype='object')

# %%
sat_act_2017_to_2018_updated_csv
# Out:
#                    state  sat_participation_17  sat_reading_and_writing_17  \
# 0                Alabama                  0.05                         593
# 1                 Alaska                  0.38                         547
# 2                Arizona                  0.30                         563
# 3               Arkansas                  0.03                         614
# 4             California                  0.53                         531
# 5               Colorado                  0.11                         606
# 6            Connecticut                  1.00                         530
# 7               Delaware                  1.00                         503
# 8   District of Columbia                  1.00                         482
# 9                Florida                  0.83                         520
# 10               Georgia                  0.61                         535
# ...

# %%
col_sat_act_2017_to_2018_updated = sat_act_2017_to_2018_updated_csv.columns.tolist()
col_sat_act_2017_to_2018_updated
# Out:
# ['state',
#  'sat_participation_17',
#  'sat_reading_and_writing_17',
#  'sat_math_17',
#  'sat_total_17',
#  'act_participation_17',
#  'act_english_17',
#  'act_math_17',
#  'act_reading_17',
#  'act_science_17',
#  'act_composite_17',
#  'sat_participation_18',
#  'sat_reading_and_writing_18',
#  'sat_math_18',
#  'sat_total_18',
#  'act_participation_18',
#  'act_composite_18',
#  'act_english_18',
#  'act_math_18',
#  'act_reading_18',
#  'act_science_18']

# %%
#Assigning new column list names for reordering sat_act_2017_to_2018_updated_csv columns' name
col_sat_act_2017_to_2018_updated = col_sat_act_2017_to_2018_updated[0:16] + col_sat_act_2017_to_2018_updated[17:21] + col_sat_act_2017_to_2018_updated[16:17]

# %%
#Rearrange new columns index 
sat_act_2017_to_2018_updated_csv = sat_act_2017_to_2018_updated_csv[col_sat_act_2017_to_2018_updated]
sat_act_2017_to_2018_updated_csv
# Out:
#                    state  sat_participation_17  sat_reading_and_writing_17  \
# 0                Alabama                  0.05                         593
# 1                 Alaska                  0.38                         547
# 2                Arizona                  0.30                         563
# 3               Arkansas                  0.03                         614
# 4             California                  0.53                         531
# 5               Colorado                  0.11                         606
# 6            Connecticut                  1.00                         530
# 7               Delaware                  1.00                         503
# 8   District of Columbia                  1.00                         482
# 9                Florida                  0.83                         520
# 10               Georgia                  0.61                         535
# ...

# %%
#Checking for any errors after rearranged columns index of sat_act_2017_to_2018_updated_csv
sat_act_2017_to_2018_updated_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   state                       51 non-null     object
#  1   sat_participation_17        51 non-null     float64
#  2   sat_reading_and_writing_17  51 non-null     int64
#  3   sat_math_17                 51 non-null     int64
#  4   sat_total_17                51 non-null     int64
#  5   act_participation_17        51 non-null     float64
#  6   act_english_17              51 non-null     float64
#  7   act_math_17                 51 non-null     float64
#  8   act_reading_17              51 non-null     float64
#  9   act_science_17              51 non-null     float64
#  10  act_composite_17            51 non-null     float64
#  11  sat_participation_18        51 non-null     float64
#  12  sat_reading_and_writing_18  51 non-null     int64
# ...

# %%
#Creating file sat_act_2017_to_2018_updated_csv to data folder
sat_act_2017_to_2018_updated_csv.to_csv('../data/sat_act_2017_to_2018_updated_csv.csv')

# %% [markdown]
# ### 2019 Data Import and Cleaning

# %% [markdown]
# Import SAT & ACT 2019 Dataset for cleaning

# %%
#Import SAT 2019 Dataset
df_sat_2019 = pd.read_csv('../data/sat_2019.csv')

# %%
df_sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
df_sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 1.7+ KB

# %%
df_sat_2019.shape
# Out:
# (53, 5)

# %%
df_sat_2019['State']
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
#Checking the equal value of  2 lists of  SAT 2019 and sat_act_2017_to_2018_csv_updated
sat_act_2017_to_2018_updated_csv_list = list(sat_act_2017_to_2018_updated_csv['state'])
df_sat_2019_list = list(df_sat_2019['State'])

# %%
#In SAT 2019 Datatset, there are more 2 states than 2017 and 2018 dataset, which are 'Puerto Rico' and 'Virgin Islands'.
#However, we need to drop these two states out of 'state' in order to make final data easily to understand and no missing values for doing EDA
(set(df_sat_2019_list).difference(sat_act_2017_to_2018_updated_csv_list))
# Out:
# {'Puerto Rico', 'Virgin Islands'}

# %%
df_sat_2019['State'][39]
# Out:
# 'Puerto Rico'

# %%
df_sat_2019['State'][47]
# Out:
# 'Virgin Islands'

# %%
df_sat_2019.drop([df_sat_2019.index[39], df_sat_2019.index[47]], inplace = True)

# %%
df_sat_2019
# Out:
#                    State Participation Rate  EBRW  Math  Total
# 0                Alabama                 7%   583   560   1143
# 1                 Alaska                41%   556   541   1097
# 2                Arizona                31%   569   565   1134
# 3               Arkansas                 6%   582   559   1141
# 4             California                63%   534   531   1065
# 5               Colorado               100%   518   506   1024
# 6            Connecticut               100%   529   516   1046
# 7               Delaware               100%   499   486    985
# 8   District of Columbia                94%   495   480    975
# 9                Florida               100%   516   483    999
# 10               Georgia                71%   538   519   1058
# 11                Hawaii                54%   550   550   1100
# 12                 Idaho               100%   505   488    993
# 13              Illinois               100%   509   504   1013
# ...

# %%
str_to_float(df_sat_2019, 'Participation Rate')
# Out:
# float64
# 0    0.07
# 1    0.41
# 2    0.31
# 3    0.06
# 4    0.63
# Name: Participation Rate, dtype: float64

# %%
df_sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               51 non-null     object
#  1   Participation Rate  51 non-null     float64
#  2   EBRW                51 non-null     int64
#  3   Math                51 non-null     int64
#  4   Total               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.2+ KB

# %%
df_sat_2019.columns
# Out:
# Index(['State', 'Participation Rate', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
#Renaming columns' name of df_act_2018_updated 
new_col_sat_19 = {'State': 'state',
                        'Participation Rate' : 'sat_participation_19',
                        'EBRW': 'sat_reading_and_writing_19',
                        'Math' : 'sat_math_19',
                        'Total' : 'sat_total_19',}
df_sat_2019.rename(columns = new_col_sat_19, inplace = True)

# %%
#Updated new columns of sat_2019 dataframe
df_sat_2019.columns
# Out:
# Index(['state', 'sat_participation_19', 'sat_reading_and_writing_19',
#        'sat_math_19', 'sat_total_19'],
#       dtype='object')

# %%
df_sat_2019.head()
# Out:
#         state  sat_participation_19  sat_reading_and_writing_19  sat_math_19  \
# 0     Alabama                  0.07                         583          560
# 1      Alaska                  0.41                         556          541
# 2     Arizona                  0.31                         569          565
# 3    Arkansas                  0.06                         582          559
# 4  California                  0.63                         534          531
#
#    sat_total_19
# 0          1143
# 1          1097
# 2          1134
# 3          1141
# 4          1065

# %%
#Checking Max and Min SAT scores which are in range 200-800 or not?
df_sat_2019.min()
# Out:
# state                         Alabama
# sat_participation_19             0.02
# sat_reading_and_writing_19        483
# sat_math_19                       460
# sat_total_19                      943
# dtype: object

# %%
df_sat_2019.max()
# Out:
# state                         Wyoming
# sat_participation_19              1.0
# sat_reading_and_writing_19        636
# sat_math_19                       648
# sat_total_19                     1284
# dtype: object

# %%
#Import ACT 2019 Dataset from outside research resoruce
df_act_2019 = pd.read_csv('../data/act_2019_score.csv')

# %%
df_act_2019.head()
# Out:
#         State Participation  English  Math  Reading  Science  Composite
# 0     Alabama          100%     18.7  18.1     19.5     18.8       18.9
# 1      Alaska           38%     18.9  19.9     20.9     20.2       20.1
# 2     Arizona           73%     17.9  19.2     19.3     19.0       19.0
# 3    Arkansas          100%     19.0  18.7     19.6     19.2       19.3
# 4  California           23%     22.4  22.3     23.0     22.2       22.6

# %%
df_act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 2.5+ KB

# %%
df_act_2019.shape
# Out:
# (52, 7)

# %%
str_to_float(df_act_2019, 'Participation')
# Out:
# float64
# 0    1.00
# 1    0.38
# 2    0.73
# 3    1.00
# 4    0.23
# Name: Participation, dtype: float64

# %%
df_act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 2.7+ KB

# %%
df_act_2019.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
#Renaming columns' name of df_act_2019 
new_col_act_19 = {'State': 'state',
                         'Participation': 'act_participation_19',
                        'English' : 'act_english_19',
                        'Math': 'act_math_19',
                        'Reading' : 'act_reading_19',
                        'Science' : 'act_science_19',
                        'Composite': 'act_composite_19'}
df_act_2019.rename(columns = new_col_act_19, inplace = True)

# %%
df_act_2019.columns
# Out:
# Index(['state', 'act_participation_19', 'act_english_19', 'act_math_19',
#        'act_reading_19', 'act_science_19', 'act_composite_19'],
#       dtype='object')

# %%
df_act_2019.head(10)
# Out:
#                   state  act_participation_19  act_english_19  act_math_19  \
# 0               Alabama                  1.00            18.7         18.1
# 1                Alaska                  0.38            18.9         19.9
# 2               Arizona                  0.73            17.9         19.2
# 3              Arkansas                  1.00            19.0         18.7
# 4            California                  0.23            22.4         22.3
# 5              Colorado                  0.27            23.8         23.3
# 6           Connecticut                  0.22            25.9         24.7
# 7              Delaware                  0.13            23.9         23.1
# 8  District of Columbia                  0.32            23.6         22.7
# 9               Florida                  0.54            19.5         19.5
#
#    act_reading_19  act_science_19  act_composite_19
# 0            19.5            18.8              18.9
# ...

# %%
#Checking the equal value of  2 lists of  SAT 2019 and sat_act_2017_to_2018_csv_updated
sat_act_2017_to_2018_updated_csv_list = list(sat_act_2017_to_2018_updated_csv['state'])
df_act_2019_list = list(df_act_2019['state'])

# %%
#In ACT 2019 Datatset, there is more 1 states than 2017 and 2018 dataset, which are 'National', so we need to drop this row.
(set(df_act_2019_list).difference(sat_act_2017_to_2018_updated_csv_list))
# Out:
# {'National'}

# %%
#Selecting row [51] to check for correct data
df_act_2019.loc[df_act_2019['state'] == 'National']
# Out:
#        state  act_participation_19  act_english_19  act_math_19  \
# 51  National                  0.52            20.1         20.4
#
#     act_reading_19  act_science_19  act_composite_19
# 51            21.2            20.6              20.7

# %%
#Drop National state in order to prepare for merging file with the latest file of 2017-2018 ACT & SAT pre final file
df_act_2019.drop(index = 51, inplace = True)

# %%
df_act_2019.shape
# Out:
# (51, 7)

# %%
#Merging SAT 2019 with ACT 2019 to update before the final file
sat_act_2019_csv = pd.merge(df_sat_2019, df_act_2019, on = 'state')

# %%
#Creating sat_act_2019 file into the data folder
sat_act_2019_csv.to_csv('../data/sat_act_2019_csv.csv')

# %%
#Last step: Create Final SAT_ACT_2017_To_2019 file in order to use in the next EDA Steps.
Final_sat_act_2017_to_2019 = pd.merge(sat_act_2017_to_2018_updated_csv, sat_act_2019_csv, on = 'state')

# %%
Final_sat_act_2017_to_2019.to_csv('../data/Final_sat_act_2017_to_2019.csv')

# %%
Final_sat_act_2017_to_2019
# Out:
#                    state  sat_participation_17  sat_reading_and_writing_17  \
# 0                Alabama                  0.05                         593
# 1                 Alaska                  0.38                         547
# 2                Arizona                  0.30                         563
# 3               Arkansas                  0.03                         614
# 4             California                  0.53                         531
# 5               Colorado                  0.11                         606
# 6            Connecticut                  1.00                         530
# 7               Delaware                  1.00                         503
# 8   District of Columbia                  1.00                         482
# 9                Florida                  0.83                         520
# 10               Georgia                  0.61                         535
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*object*|Final_sat_act_2017_to_2019|Names of all US states and the District of Columbia|
# |**sat_participation_17**|*float*|Final_sat_act_2017_to_2019|The percentage of 2017 graduating seniors who took the SAT|
# |**sat_reading_and_writing_17**|*int*|Final_sat_act_2017_to_2019|The mean score of the Evidence-Based Reading and Writing (ERW) category of the SAT in 2017 (score range: 200-800)|
# |**sat_math_17**|*int*|Final_sat_act_2017_to_2019|The mean score of the Math category of the SAT in 2017 (score range: 200-800)|
# |**sat_total_17**|*int*|Final_sat_act_2017_to_2019|The sum of the mean scores of ERW and Math in the SAT in 2017 (score range: 400-1600)|
# |**sat_participation_18**|*float*|Final_sat_act_2017_to_2019|The percentage of 2018 graduating seniors who took the SAT|
# |**sat_reading_and_writing_18**|*int*|Final_sat_act_2017_to_2019|The mean score of the Evidence-Based Reading and Writing (ERW) category of the SAT in 2018 (score range: 200-800)|
# |**sat_math_18**|*int*|Final_sat_act_2017_to_2019|The mean score of the Math category of the SAT in 2018 (score range: 200-800)|
# |**sat_total_18**|*int*|Final_sat_act_2017_to_2019|The sum of the mean scores of ERW and Math in the SAT in 2018 (score range: 400-1600)|
# |**sat_participation_19**|*float*|Final_sat_act_2017_to_2019|The percentage of 2019 graduating seniors who took the SAT|
# |**sat_reading_and_writing_19**|*int*|Final_sat_act_2017_to_2019|The mean score of the Evidence-Based Reading and Writing (ERW) category of the SAT in 2019 (score range: 200-800)|
# |**sat_math_19**|*int*|Final_sat_act_2017_to_2019|The mean score of the Math category of the SAT in 2019 (score range: 200-800)|
# |**sat_total_19**|*int*|Final_sat_act_2017_to_2019|The sum of the mean scores of ERW and Math in the SAT in 2019 (score range: 400-1600)|
# |**act_participation_17**|*float*|Final_sat_act_2017_to_2019|The percentage of 2017 graduating seniors who took the ACT (0.9810 means 98.1%)|
# |**act_english_17**|*float*|Final_sat_act_2017_to_2019|The mean score of the Reading category of the ACT in 2017 (score range: 1-36)|
# |**act_math_17**|*float*|Final_sat_act_2017_to_2019|The mean score of the Math category of the ACT in 2017 (score range: 1-36)|
# |**act_reading_17**|*float*|Final_sat_act_2017_to_2019|The mean score of the Reading category of the ACT in 2017 (score range: 1-36)|
# |**act_science_17**|*float*|Final_sat_act_2017_to_2019|The mean score of the Science category of the ACT in 2017 (score range: 1-36)|
# |**act_composite_17**|*float*|Final_sat_act_2017_to_2019|The mean score of the categories English, Math, Reading, and Science on the ACT in 2017 (score range: 1-36)|
# |**act_participation_18**|*float*|Final_sat_act_2017_to_2019|The percentage of 2018 graduating seniors who took the ACT (0.9810 means 98.1%)|
# |**act_english_18**|*float*|Final_sat_act_2017_to_2019|The mean score of the Reading category of the ACT in 2018 (score range: 1-36)|
# |**act_math_18**|*float*|Final_sat_act_2017_to_2019|The mean score of the Math category of the ACT in 2018 (score range: 1-36)|
# |**act_reading_18**|*float*|Final_sat_act_2017_to_2019|The mean score of the Reading category of the ACT in 2018 (score range: 1-36)|
# |**act_science_18**|*float*|Final_sat_act_2017_to_2019|The mean score of the Science category of the ACT in 2018 (score range: 1-36)|
# |**act_composite_18**|*float*|Final_sat_act_2017_to_2019|The mean score of the categories English, Math, Reading, and Science on the ACT in 2018 (score range: 1-36)|
# |**act_participation_19**|*float*|Final_sat_act_2017_to_2019|The percentage of 2019 graduating seniors who took the ACT (0.9810 means 98.1%)|
# |**act_english_19**|*float*|Final_sat_act_2017_to_2019|The mean score of the Reading category of the ACT in 2019 (score range: 1-36)|
# |**act_math_19**|*float*|Final_sat_act_2017_to_2019|The mean score of the Math category of the ACT in 2019 (score range: 1-36)|
# |**act_reading_19**|*float*|Final_sat_act_2017_to_2019|The mean score of the Reading category of the ACT in 2019 (score range: 1-36)|
# |**act_science_19**|*float*|Final_sat_act_2017_to_2019|The mean score of the Science category of the ACT in 2019 (score range: 1-36)|
# |**act_composite_19**|*float*|Final_sat_act_2017_to_2019|The mean score of the categories English, Math, Reading, and Science on the ACT in 2019 (score rane: 1-36)|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
summary_final_data = Final_sat_act_2017_to_2019.describe().round(1)
summary_final_data.transpose()
# Out:
#                             count    mean   std    min     25%     50%  \
# sat_participation_17         51.0     0.4   0.4    0.0     0.0     0.4
# sat_reading_and_writing_17   51.0   569.1  45.7  482.0   533.5   559.0
# sat_math_17                  51.0   556.9  47.1  468.0   523.5   548.0
# sat_total_17                 51.0  1126.1  92.5  950.0  1055.5  1107.0
# act_participation_17         51.0     0.7   0.3    0.1     0.3     0.7
# act_english_17               51.0    20.9   2.4   16.3    19.0    20.7
# act_math_17                  51.0    21.2   2.0   18.0    19.4    20.9
# act_reading_17               51.0    22.0   2.1   18.1    20.4    21.8
# act_science_17               51.0    21.0   3.2    2.3    19.9    21.3
# act_composite_17             51.0    21.5   2.0   17.8    19.8    21.4
# sat_participation_18         51.0     0.5   0.4    0.0     0.0     0.5
# sat_reading_and_writing_18   51.0   563.7  47.5  480.0   534.5   552.0
# ...

# %% [markdown]
# ## Standard Deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$

# %%
# Code:
def std_dev(some_list):
    mean_sum = 0
    for num in some_list: 
        mean_sum += num
    mean_list = mean_sum/len(some_list)
    
    var_sum = 0
    for num in some_list: 
        var_sum += ((num - mean_list) ** 2)
    std_list = (var_sum * (1/len(some_list))) ** (1/2)
    
    return std_list

# %%
#Create function std by using Dictionary Comprehension to apply to each columns in the final act and sat data frame

sd = {col : round(std_dev(Final_sat_act_2017_to_2019[col]),4) for col in Final_sat_act_2017_to_2019.columns if ((Final_sat_act_2017_to_2019[col].dtypes == float) | (Final_sat_act_2017_to_2019[col].dtype == 'int64'))}
sd
# Out:
# {'sat_participation_17': 0.3493,
#  'sat_reading_and_writing_17': 45.217,
#  'sat_math_17': 46.6571,
#  'sat_total_17': 91.5835,
#  'act_participation_17': 0.3182,
#  'act_english_17': 2.3305,
#  'act_math_17': 1.9625,
#  'act_reading_17': 2.0469,
#  'act_science_17': 3.1511,
#  'act_composite_17': 2.0008,
#  'sat_participation_18': 0.3695,
#  'sat_reading_and_writing_18': 47.0346,
#  'sat_math_18': 47.3019,
#  'sat_total_18': 93.2274,
#  'act_participation_18': 0.337,
#  'act_english_18': 2.4223,
#  'act_math_18': 2.0157,
#  'act_reading_18': 2.1459,
#  'act_science_18': 1.8517,
#  'act_composite_18': 2.0908,
#  'sat_participation_19': 0.3837,
#  'sat_reading_and_writing_19': 45.7924,
#  'sat_math_19': 50.7852,
#  'sat_total_19': 96.2403,
#  'act_participation_19': 0.3418,
#  'act_english_19': 2.5003,
#  'act_math_19': 2.0822,
#  'act_reading_19': 2.2349,
#  'act_science_19': 1.9523,
#  'act_composite_19': 2.1729}

# %% [markdown]
# #### Investigating trends in data

# %%
#Finding the highest and lowest participation rates for the 2017, 2018, 2019 SAT

# %%
#Creating mask for doing EDA
mask_sat_part_above_50 = Final_sat_act_2017_to_2019[['sat_participation_17', 'sat_participation_18', 'sat_participation_19']] > 50
mask_act_part_above_50 = Final_sat_act_2017_to_2019[['act_participation_17', 'act_participation_18', 'act_participation_19']] > 50

mask_sat_part_100 = Final_sat_act_2017_to_2019[['sat_participation_17', 'sat_participation_18', 'sat_participation_19']] == 100
mask_act_part_100 = Final_sat_act_2017_to_2019[['act_participation_17', 'act_participation_18', 'act_participation_19']] == 100

# %% [markdown]
# #### The 5 of Highest and Lowest participation rates for the
#
# #### 2017 SAT:
# - Highest: Distric of Columbia, Michigan, Connecticut, Delaware, New Hampshire
# - Lowest: North Dakota, Mississippi, Lowa, Missouri, Utah
#
# #### 2018 SAT:
# - Highest: Colorado, Connecticut, Delaware, Michigan, Idaho
# - Lowest: North Dakota, Wyoming, South Dakota, Nebraska, Wisconsin
#
# #### 2019 SAT:
# - Highest: Rhode Island, Illinois, Michigan, Colorado, Connecticut
# - Lowest: North Dakota, Wyoming, South Dakota, Nebraska, Wisconsin
#
# #### 2017 ACT:
# - Highest: Alabama, Kentucky, Wisconsin, Utha, Tennessee
# - Lowest: Maine, New Hampshire, Delaware, Rhode Island, Pennsylvania
#
# #### 2018 ACT:
# - Highest: Alabama, Kentucky, Wisconsin, Utah, Tennessee
# - Lowest: Maine, Rhode Island, New Hampshire, Delaware, Pennsylvania
#
# #### 2019 ACT:
# - Highest: Alabama, Kentucky, Wisconsin, Utah, Tennessee
# - Lowest: Maine, Rhode Island, Delaware, New Hampshire, Pennsylvania

# %% [markdown]
# ### SAT 2017 - 2019 Highest and Lowerst Participation rates

# %%
#SAT 2017 Top 5 Highest Participation rate: Distric of Columbia, Michigan, Connecticut, Delaware, New Hampshire
sat_2017_high_participation = Final_sat_act_2017_to_2019.sort_values('sat_participation_17', ascending = False)
sat_2017_high_participation.head()
# Out:
#                    state  sat_participation_17  sat_reading_and_writing_17  \
# 8   District of Columbia                  1.00                         482
# 22              Michigan                  1.00                         509
# 6            Connecticut                  1.00                         530
# 7               Delaware                  1.00                         503
# 29         New Hampshire                  0.96                         532
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 8           468           950                  0.32            24.4
# 22          495          1005                  0.29            24.1
# 6           512          1041                  0.31            25.5
# 7           492           996                  0.18            24.1
# 29          520          1052                  0.18            25.4
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#SAT 2017 Top 5 Lowest Participation rate: North Dakota, Mississippi, Lowa, Missouri, Utah
sat_2017_high_participation = Final_sat_act_2017_to_2019.sort_values('sat_participation_17', ascending = True)
sat_2017_high_participation.head()
# Out:
#            state  sat_participation_17  sat_reading_and_writing_17  \
# 34  North Dakota                  0.02                         635
# 24   Mississippi                  0.02                         634
# 15          Iowa                  0.02                         641
# 25      Missouri                  0.03                         640
# 44          Utah                  0.03                         624
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 34          621          1256                  0.98            19.0
# 24          607          1242                  1.00            18.2
# 15          635          1275                  0.67            21.2
# 25          631          1271                  1.00            19.8
# 44          614          1238                  1.00            19.5
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#SAT 2018 Top 5 Highest Participation rate: Colorado, Connecticut, Delaware, Michigan, Idaho
sat_2018_high_participation = Final_sat_act_2017_to_2019.sort_values('sat_participation_18', ascending = False)
sat_2018_high_participation.head()
# Out:
#           state  sat_participation_17  sat_reading_and_writing_17  \
# 5      Colorado                  0.11                         606
# 6   Connecticut                  1.00                         530
# 7      Delaware                  1.00                         503
# 22     Michigan                  1.00                         509
# 12        Idaho                  0.93                         513
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 5           595          1201                  1.00            20.1
# 6           512          1041                  0.31            25.5
# 7           492           996                  0.18            24.1
# 22          495          1005                  0.29            24.1
# 12          493          1005                  0.38            21.9
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# 5          20.3            21.2            20.9  ...                   1.0
# ...

# %%
#SAT 2018 Top 5 Lowest Participation rate: North Dakota, Wyoming, South Dakota, Nebraska, Wisconsin
sat_2018_high_participation = Final_sat_act_2017_to_2019.sort_values('sat_participation_18', ascending = True)
sat_2018_high_participation.head()
# Out:
#            state  sat_participation_17  sat_reading_and_writing_17  \
# 34  North Dakota                  0.02                         635
# 50       Wyoming                  0.03                         626
# 41  South Dakota                  0.03                         612
# 27      Nebraska                  0.03                         629
# 49     Wisconsin                  0.03                         642
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 34          621          1256                  0.98            19.0
# 50          604          1230                  1.00            19.4
# 41          603          1216                  0.80            20.7
# 27          625          1253                  0.84            20.9
# 49          649          1291                  1.00            19.7
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#SAT 2019 Top 5 Highest Participation rate: Rhode Island, Illinois, Michigan, Colorado, Connecticut
sat_2019_high_participation = Final_sat_act_2017_to_2019.sort_values('sat_participation_19', ascending = False)
sat_2019_high_participation.head()
# Out:
#            state  sat_participation_17  sat_reading_and_writing_17  \
# 39  Rhode Island                  0.71                         539
# 13      Illinois                  0.09                         559
# 22      Michigan                  1.00                         509
# 5       Colorado                  0.11                         606
# 6    Connecticut                  1.00                         530
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 39          524          1062                  0.21            24.0
# 13          556          1115                  0.93            21.0
# 22          495          1005                  0.29            24.1
# 5           595          1201                  1.00            20.1
# 6           512          1041                  0.31            25.5
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#SAT 2019 Top 5 Lowest Participation rate: North Dakota, Wyoming, South Dakota, Nebraska, Wisconsin
sat_2019_high_participation = Final_sat_act_2017_to_2019.sort_values('sat_participation_19', ascending = True)
sat_2019_high_participation.head()
# Out:
#            state  sat_participation_17  sat_reading_and_writing_17  \
# 34  North Dakota                  0.02                         635
# 50       Wyoming                  0.03                         626
# 41  South Dakota                  0.03                         612
# 27      Nebraska                  0.03                         629
# 49     Wisconsin                  0.03                         642
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 34          621          1256                  0.98            19.0
# 50          604          1230                  1.00            19.4
# 41          603          1216                  0.80            20.7
# 27          625          1253                  0.84            20.9
# 49          649          1291                  1.00            19.7
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
Final_sat_act_2017_to_2019[['state', 'sat_participation_17', 'sat_participation_18', 'sat_participation_19']].sort_values('sat_participation_17', ascending = True)
# Out:
#                    state  sat_participation_17  sat_participation_18  \
# 34          North Dakota                  0.02                  0.02
# 24           Mississippi                  0.02                  0.03
# 15                  Iowa                  0.02                  0.03
# 25              Missouri                  0.03                  0.04
# 44                  Utah                  0.03                  0.04
# 41          South Dakota                  0.03                  0.03
# 27              Nebraska                  0.03                  0.03
# 49             Wisconsin                  0.03                  0.03
# 23             Minnesota                  0.03                  0.04
# 50               Wyoming                  0.03                  0.03
# 3               Arkansas                  0.03                  0.05
# 16                Kansas                  0.04                  0.04
# 17              Kentucky                  0.04                  0.04
# ...

# %%
#Finding the highest and lowest participation rates for the 2017, 2018, 2019 ACT

# %%
#ACT 2017 Top 5 Highest Participation rate: Alabama, Kentucky, Wisconsin, Utha, Tennessee, Soth Carolina, Oklahoma, North Carolina, Nevada, Montana
act_2017_high_participation = Final_sat_act_2017_to_2019.sort_values('act_participation_17', ascending = False)
act_2017_high_participation.head(10)
# Out:
#              state  sat_participation_17  sat_reading_and_writing_17  \
# 0          Alabama                  0.05                         593
# 17        Kentucky                  0.04                         631
# 49       Wisconsin                  0.03                         642
# 44            Utah                  0.03                         624
# 42       Tennessee                  0.05                         623
# 40  South Carolina                  0.50                         543
# 36        Oklahoma                  0.07                         530
# 33  North Carolina                  0.49                         546
# 28          Nevada                  0.26                         563
# 26         Montana                  0.10                         605
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 0           572          1165                   1.0            18.9
# 17          616          1247                   1.0            19.6
# ...

# %%
#ACT 2017 Top 5 Lowest Participation rate: Maine, New Hampshire, Delaware, Rhode Island, Pennsylvania
act_2017_high_participation = Final_sat_act_2017_to_2019.sort_values('act_participation_17', ascending = True)
act_2017_high_participation.head()
# Out:
#             state  sat_participation_17  sat_reading_and_writing_17  \
# 19          Maine                  0.95                         513
# 29  New Hampshire                  0.96                         532
# 7        Delaware                  1.00                         503
# 39   Rhode Island                  0.71                         539
# 38   Pennsylvania                  0.65                         540
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 19          499          1012                  0.08            24.2
# 29          520          1052                  0.18            25.4
# 7           492           996                  0.18            24.1
# 39          524          1062                  0.21            24.0
# 38          531          1071                  0.23            23.4
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#ACT 2018 Top 5 Highest Participation rate: Alabama, Kentucky, Wisconsin, Utah, Tennessee
act_2018_high_participation = Final_sat_act_2017_to_2019.sort_values('act_participation_18', ascending = False)
act_2018_high_participation.head(10)
# Out:
#              state  sat_participation_17  sat_reading_and_writing_17  \
# 0          Alabama                  0.05                         593
# 17        Kentucky                  0.04                         631
# 49       Wisconsin                  0.03                         642
# 44            Utah                  0.03                         624
# 42       Tennessee                  0.05                         623
# 40  South Carolina                  0.50                         543
# 36        Oklahoma                  0.07                         530
# 35            Ohio                  0.12                         578
# 33  North Carolina                  0.49                         546
# 28          Nevada                  0.26                         563
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 0           572          1165                  1.00            18.9
# 17          616          1247                  1.00            19.6
# ...

# %%
#ACT 2018 Top 5 Lowest Participation rate: Maine, Rhode Island, New Hampshire, Delaware, Pennsylvania
act_2018_high_participation = Final_sat_act_2017_to_2019.sort_values('act_participation_18', ascending = True)
act_2018_high_participation.head()
# Out:
#             state  sat_participation_17  sat_reading_and_writing_17  \
# 19          Maine                  0.95                         513
# 39   Rhode Island                  0.71                         539
# 29  New Hampshire                  0.96                         532
# 7        Delaware                  1.00                         503
# 38   Pennsylvania                  0.65                         540
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 19          499          1012                  0.08            24.2
# 39          524          1062                  0.21            24.0
# 29          520          1052                  0.18            25.4
# 7           492           996                  0.18            24.1
# 38          531          1071                  0.23            23.4
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#ACT 2019 Top 5 Highest Participation rate: Alabama, Kentucky, Wisconsin, Utah, Tennessee
act_2019_high_participation = Final_sat_act_2017_to_2019.sort_values('act_participation_19', ascending = False)
act_2019_high_participation.head()
# Out:
#         state  sat_participation_17  sat_reading_and_writing_17  sat_math_17  \
# 0     Alabama                  0.05                         593          572
# 17   Kentucky                  0.04                         631          616
# 49  Wisconsin                  0.03                         642          649
# 44       Utah                  0.03                         624          614
# 42  Tennessee                  0.05                         623          604
#
#     sat_total_17  act_participation_17  act_english_17  act_math_17  \
# 0           1165                   1.0            18.9         18.4
# 17          1247                   1.0            19.6         19.4
# 49          1291                   1.0            19.7         20.4
# 44          1238                   1.0            19.5         19.9
# 42          1228                   1.0            19.5         19.2
#
#     act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#ACT 2019 Top 5 Lowest Participation rate: Maine, Rhode Island, Delaware, New Hampshire, Pennsylvania
act_2019_high_participation = Final_sat_act_2017_to_2019.sort_values('act_participation_19', ascending = True)
act_2019_high_participation.head()
# Out:
#             state  sat_participation_17  sat_reading_and_writing_17  \
# 19          Maine                  0.95                         513
# 39   Rhode Island                  0.71                         539
# 7        Delaware                  1.00                         503
# 29  New Hampshire                  0.96                         532
# 38   Pennsylvania                  0.65                         540
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 19          499          1012                  0.08            24.2
# 39          524          1062                  0.21            24.0
# 7           492           996                  0.18            24.1
# 29          520          1052                  0.18            25.4
# 38          531          1071                  0.23            23.4
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %% [markdown]
# ### SAT 2017 - 2019 Highest and Lowerst average/mean of Total Composite scores

# %% [markdown]
# #### The 5 of Highest and Lowest average/mean of total composite scores
#
# #### 2017 SAT:
# - Highest: Minnesota, Wisconsin, Lowa, Missouri, Kansas
# - Lowest: District of Columbia, Delaware, Idaho, Michigan, Maine
#
# #### 2018 SAT:
# - Highest: Minnesota, Wisconsin, North Dakota, Lowa, Kansas
# - Lowest: District of Columbia, Delaware, West Virginia , Idaho, Utah
#
# #### 2019 SAT:
# - Highest: Minnesota, Wisconsin, South Dakota, North Dakota, Nebraska
# - Lowest: West Virginia, Oklahoma, District of Columbia, Delaware, Idaho
#
# #### 2017 ACT:
# - Highest: New Hampshire, Massachusetts, Connecticut, Maine, District of Columbia
# - Lowest: Nevada, Mississippi, South Carolina, Hawaii, North Carolina
#
# #### 2018 ACT:
# - Highest: Connecticut, Massachusetts, New Hampshire, New York, Michigan
# - Lowest: Nevada, South Carolina, Mississippi, Hawaii, Alabama
#
# #### 2019 ACT:
# - Highest: Massachusetts, Connecticut, New Hampshire, Rhode Island, New York
# - Lowest: Nevada, Mississippi, South Carolina, Louisiana, Alabama

# %%
#SAT 2017 Top 5 Highest Total Scores: Minnesota, Wisconsin, Lowa, Missouri, Kansas
sat_2017_high_total = Final_sat_act_2017_to_2019.sort_values('sat_total_17', ascending = False)
sat_2017_high_total.head()
# Out:
#         state  sat_participation_17  sat_reading_and_writing_17  sat_math_17  \
# 23  Minnesota                  0.03                         644          651
# 49  Wisconsin                  0.03                         642          649
# 15       Iowa                  0.02                         641          635
# 25   Missouri                  0.03                         640          631
# 16     Kansas                  0.04                         632          628
#
#     sat_total_17  act_participation_17  act_english_17  act_math_17  \
# 23          1295                  1.00            20.4         21.5
# 49          1291                  1.00            19.7         20.4
# 15          1275                  0.67            21.2         21.3
# 25          1271                  1.00            19.8         19.9
# 16          1260                  0.73            21.1         21.3
#
#     act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#SAT 2017 Top 5 Lowest Total Scores: District of Columbia, Delaware, Idaho, Michigan, Maine
sat_2017_high_total = Final_sat_act_2017_to_2019.sort_values('sat_total_17', ascending = True)
sat_2017_high_total.head()
# Out:
#                    state  sat_participation_17  sat_reading_and_writing_17  \
# 8   District of Columbia                  1.00                         482
# 7               Delaware                  1.00                         503
# 12                 Idaho                  0.93                         513
# 22              Michigan                  1.00                         509
# 19                 Maine                  0.95                         513
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 8           468           950                  0.32            24.4
# 7           492           996                  0.18            24.1
# 12          493          1005                  0.38            21.9
# 22          495          1005                  0.29            24.1
# 19          499          1012                  0.08            24.2
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#SAT 2018 Top 5 Highest Total Scores: Minnesota, Wisconsin, North Dakota, Lowa, Kansas
sat_2018_high_total = Final_sat_act_2017_to_2019.sort_values('sat_total_18', ascending = False)
sat_2018_high_total.head()
# Out:
#            state  sat_participation_17  sat_reading_and_writing_17  \
# 23     Minnesota                  0.03                         644
# 49     Wisconsin                  0.03                         642
# 34  North Dakota                  0.02                         635
# 15          Iowa                  0.02                         641
# 16        Kansas                  0.04                         632
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 23          651          1295                  1.00            20.4
# 49          649          1291                  1.00            19.7
# 34          621          1256                  0.98            19.0
# 15          635          1275                  0.67            21.2
# 16          628          1260                  0.73            21.1
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#SAT 2018 Top 5 Lowest Total Scores: District of Columbia, Delaware, West Virginia , Idaho, Utah
sat_2018_high_total = Final_sat_act_2017_to_2019.sort_values('sat_total_18', ascending = True)
sat_2018_high_total.head()
# Out:
#                    state  sat_participation_17  sat_reading_and_writing_17  \
# 8   District of Columbia                  1.00                         482
# 7               Delaware                  1.00                         503
# 48         West Virginia                  0.14                         558
# 12                 Idaho                  0.93                         513
# 44                  Utah                  0.03                         624
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 8           468           950                  0.32            24.4
# 7           492           996                  0.18            24.1
# 48          528          1086                  0.69            20.0
# 12          493          1005                  0.38            21.9
# 44          614          1238                  1.00            19.5
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#SAT 2019 Top 5 Highest Total Scores: Minnesota, Wisconsin, South Dakota, North Dakota, Nebraska
sat_2019_high_total = Final_sat_act_2017_to_2019.sort_values('sat_total_19', ascending = False)
sat_2019_high_total.head()
# Out:
#            state  sat_participation_17  sat_reading_and_writing_17  \
# 23     Minnesota                  0.03                         644
# 49     Wisconsin                  0.03                         642
# 41  South Dakota                  0.03                         612
# 34  North Dakota                  0.02                         635
# 27      Nebraska                  0.03                         629
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 23          651          1295                  1.00            20.4
# 49          649          1291                  1.00            19.7
# 41          603          1216                  0.80            20.7
# 34          621          1256                  0.98            19.0
# 27          625          1253                  0.84            20.9
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#SAT 2019 Top 5 Lowest Total Scores: West Virginia, Oklahoma, District of Columbia, Delaware, Idaho
sat_2019_high_total = Final_sat_act_2017_to_2019.sort_values('sat_total_19', ascending = True)
sat_2019_high_total.head()
# Out:
#                    state  sat_participation_17  sat_reading_and_writing_17  \
# 48         West Virginia                  0.14                         558
# 36              Oklahoma                  0.07                         530
# 8   District of Columbia                  1.00                         482
# 7               Delaware                  1.00                         503
# 12                 Idaho                  0.93                         513
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 48          528          1086                  0.69            20.0
# 36          517          1047                  1.00            18.5
# 8           468           950                  0.32            24.4
# 7           492           996                  0.18            24.1
# 12          493          1005                  0.38            21.9
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#Act 2017 Top 5 Highest Total Scores: New Hampshire, Massachusetts, Connecticut, Maine, District of Columbia
act_2017_high_total = Final_sat_act_2017_to_2019.sort_values('act_composite_17', ascending = False)
act_2017_high_total.head()
# Out:
#                    state  sat_participation_17  sat_reading_and_writing_17  \
# 29         New Hampshire                  0.96                         532
# 21         Massachusetts                  0.76                         555
# 6            Connecticut                  1.00                         530
# 19                 Maine                  0.95                         513
# 8   District of Columbia                  1.00                         482
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 29          520          1052                  0.18            25.4
# 21          551          1107                  0.29            25.4
# 6           512          1041                  0.31            25.5
# 19          499          1012                  0.08            24.2
# 8           468           950                  0.32            24.4
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#Act 2017 Top 5 Lowest Total Scores: Nevada, Mississippi, South Carolina, Hawaii, North Carolina
act_2017_high_total = Final_sat_act_2017_to_2019.sort_values('act_composite_17', ascending = True)
act_2017_high_total.head()
# Out:
#              state  sat_participation_17  sat_reading_and_writing_17  \
# 28          Nevada                  0.26                         563
# 24     Mississippi                  0.02                         634
# 40  South Carolina                  0.50                         543
# 11          Hawaii                  0.55                         544
# 33  North Carolina                  0.49                         546
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 28          553          1116                   1.0            16.3
# 24          607          1242                   1.0            18.2
# 40          521          1064                   1.0            17.5
# 11          541          1085                   0.9            17.8
# 33          535          1081                   1.0            17.8
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#Act 2018 Top 5 Highest Total Scores: Connecticut, Massachusetts, New Hampshire, New York, Michigan
act_2018_high_total = Final_sat_act_2017_to_2019.sort_values('act_composite_18', ascending = False)
act_2018_high_total.head()
# Out:
#             state  sat_participation_17  sat_reading_and_writing_17  \
# 6     Connecticut                  1.00                         530
# 21  Massachusetts                  0.76                         555
# 29  New Hampshire                  0.96                         532
# 32       New York                  0.67                         528
# 22       Michigan                  1.00                         509
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 6           512          1041                  0.31            25.5
# 21          551          1107                  0.29            25.4
# 29          520          1052                  0.18            25.4
# 32          523          1052                  0.31            23.8
# 22          495          1005                  0.29            24.1
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#Act 2018 Top 5 Lowest Total Scores: Nevada, South Carolina, Mississippi, Hawaii, Alabama
act_2018_high_total = Final_sat_act_2017_to_2019.sort_values('act_composite_18', ascending = True)
act_2018_high_total.head()
# Out:
#              state  sat_participation_17  sat_reading_and_writing_17  \
# 28          Nevada                  0.26                         563
# 40  South Carolina                  0.50                         543
# 24     Mississippi                  0.02                         634
# 11          Hawaii                  0.55                         544
# 0          Alabama                  0.05                         593
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 28          553          1116                   1.0            16.3
# 40          521          1064                   1.0            17.5
# 24          607          1242                   1.0            18.2
# 11          541          1085                   0.9            17.8
# 0           572          1165                   1.0            18.9
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#Act 2019 Top 5 Highest Total Scores: Massachusetts, Connecticut, New Hampshire, Rhode Island, New York
act_2019_high_total = Final_sat_act_2017_to_2019.sort_values('act_composite_19', ascending = False)
act_2019_high_total.head()
# Out:
#             state  sat_participation_17  sat_reading_and_writing_17  \
# 21  Massachusetts                  0.76                         555
# 6     Connecticut                  1.00                         530
# 29  New Hampshire                  0.96                         532
# 39   Rhode Island                  0.71                         539
# 32       New York                  0.67                         528
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 21          551          1107                  0.29            25.4
# 6           512          1041                  0.31            25.5
# 29          520          1052                  0.18            25.4
# 39          524          1062                  0.21            24.0
# 32          523          1052                  0.31            23.8
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
#Act 2019 Top 5 Lowest Total Scores: Nevada, Mississippi, South Carolina, Louisiana, Alabama
act_2019_high_total = Final_sat_act_2017_to_2019.sort_values('act_composite_19', ascending = True)
act_2019_high_total.head()
# Out:
#              state  sat_participation_17  sat_reading_and_writing_17  \
# 28          Nevada                  0.26                         563
# 24     Mississippi                  0.02                         634
# 40  South Carolina                  0.50                         543
# 18       Louisiana                  0.04                         611
# 0          Alabama                  0.05                         593
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 28          553          1116                   1.0            16.3
# 24          607          1242                   1.0            18.2
# 40          521          1064                   1.0            17.5
# 18          586          1198                   1.0            19.4
# 0           572          1165                   1.0            18.9
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %% [markdown]
# ## Do any states with 100% participation on a given test have a rate change year-to-year?

# %% [markdown]
# ### The following states had a 100% participation rate in 2017 but not in 2018:
#     -SAT: Distric of Columbia
#     -ACT: Colorado, Minnesota
#
# ### The following states had a 100% participation rate in 2018 but not in 2019:
#     -SAT: {None of any states}
#     -ACT: Missouri, Colorado, Minnesota, South Carolina
#     #Interpret: States that have 100% participation rate in SAT 2018 also have 100% participation rate in SAT 2019

# %%
#Creating mask for doing EDA
mask_sat_part_above_50 = Final_sat_act_2017_to_2019[['sat_participation_17', 'sat_participation_18', 'sat_participation_19']] > 0.5
mask_act_part_above_50 = Final_sat_act_2017_to_2019[['act_participation_17', 'act_participation_18', 'act_participation_19']] > 0.5

mask_sat_part_100 = Final_sat_act_2017_to_2019[['sat_participation_17', 'sat_participation_18', 'sat_participation_19']] == 1
mask_act_part_100 = Final_sat_act_2017_to_2019[['act_participation_17', 'act_participation_18', 'act_participation_19']] == 1

# %%
#SAT Test
# find states with 100% participation rates in 2017
sat_2017_participation = Final_sat_act_2017_to_2019[mask_sat_part_100['sat_participation_17']]
set_sat_participation_2017 =set(sat_2017_participation['state'].sort_values())
print(set_sat_participation_2017)

# find states with 100% participation rates in 2018
sat_2018_participation = Final_sat_act_2017_to_2019[mask_sat_part_100['sat_participation_18']]
set_sat_participation_2018 =set(sat_2018_participation['state'].sort_values())
print(set_sat_participation_2018)

# find states with 100% participation rates in 2019
sat_2019_participation = Final_sat_act_2017_to_2019[mask_sat_part_100['sat_participation_19']]
set_sat_participation_2019 =set(sat_2019_participation['state'].sort_values())
print(set_sat_participation_2019)

# The states that have 100% participation in 2017 but <100% in 2018
set_sat_changed_17_and_18 = set_sat_participation_2017 - set_sat_participation_2018
print(set_sat_changed_17_and_18)

# The states that have 100% participation in 2018 but <100% in 2019
set_sat_changed_18_and_19 = set_sat_participation_2018 - set_sat_participation_2019
print(set_sat_changed_18_and_19)

# The states that have 100% participation in 2017 but <100% in 2019
set_sat_changed_17_and_19 = set_sat_participation_2017 - set_sat_participation_2019
print(set_sat_changed_17_and_19)
# Out:
# {'Delaware', 'Michigan', 'District of Columbia', 'Connecticut'}
# {'Idaho', 'Delaware', 'Colorado', 'Michigan', 'Connecticut'}
# {'Idaho', 'Illinois', 'Delaware', 'Rhode Island', 'Connecticut', 'Colorado', 'Michigan', 'Florida'}
# {'District of Columbia'}
# set()
# {'District of Columbia'}

# %%
#ACT Test
# find states with 100% participation rates in 2017
act_2017_participation = Final_sat_act_2017_to_2019[mask_act_part_100['act_participation_17']]
set_act_participation_2017 =set(act_2017_participation['state'].sort_values())
print(set_act_participation_2017)

# find states with 100% participation rates in 2018
act_2018_participation = Final_sat_act_2017_to_2019[mask_act_part_100['act_participation_18']]
set_act_participation_2018 =set(act_2018_participation['state'].sort_values())
print(set_act_participation_2018)

# find states with 100% participation rates in 2019
act_2019_participation = Final_sat_act_2017_to_2019[mask_act_part_100['act_participation_19']]
set_act_participation_2019 =set(act_2019_participation['state'].sort_values())
print(set_act_participation_2019)

# The states that have 100% participation in 2017 but <100% in 2018
set_act_changed_17_and_18 = set_act_participation_2017 - set_act_participation_2018
print(set_act_changed_17_and_18)

# The states that have 100% participation in 2018 but <100% in 2019
set_act_changed_18_and_19 = set_act_participation_2017 - set_act_participation_2018
print(set_act_changed_18_and_19)

# The states that have 100% participation in 2017 but <100% in 2019
set_act_changed_17_and_19 = set_act_participation_2017 - set_act_participation_2019
print(set_act_changed_17_and_19)
# Out:
# {'Oklahoma', 'Wisconsin', 'Kentucky', 'Minnesota', 'Missouri', 'Montana', 'Nevada', 'Louisiana', 'Arkansas', 'Colorado', 'North Carolina', 'Alabama', 'Tennessee', 'South Carolina', 'Wyoming', 'Mississippi', 'Utah'}
# {'Oklahoma', 'Wisconsin', 'Kentucky', 'Missouri', 'Montana', 'Nevada', 'Louisiana', 'Arkansas', 'Nebraska', 'North Carolina', 'Alabama', 'Tennessee', 'South Carolina', 'Wyoming', 'Mississippi', 'Ohio', 'Utah'}
# {'Oklahoma', 'Wisconsin', 'Kentucky', 'Nevada', 'Montana', 'Louisiana', 'Arkansas', 'Nebraska', 'North Carolina', 'Alabama', 'Tennessee', 'Wyoming', 'Mississippi', 'Ohio', 'Utah'}
# {'Colorado', 'Minnesota'}
# {'Colorado', 'Minnesota'}
# {'Missouri', 'Colorado', 'Minnesota', 'South Carolina'}

# %%
{'Oklahoma', 'Wisconsin', 'Kentucky', 'Minnesota', 'Missouri', 'Montana', 'Nevada', 'Louisiana', 'Arkansas', 'Colorado', 'North Carolina', 'Alabama', 'Tennessee', 'South Carolina', 'Wyoming', 'Mississippi', 'Utah'}
{'Oklahoma', 'Wisconsin', 'Kentucky', 'Missouri', 'Montana', 'Nevada', 'Louisiana', 'Arkansas', 'Nebraska', 'North Carolina', 'Alabama', 'Tennessee', 'South Carolina', 'Wyoming', 'Mississippi', 'Ohio', 'Utah'}
{'Oklahoma', 'Wisconsin', 'Kentucky', 'Nevada', 'Montana', 'Louisiana', 'Arkansas', 'Nebraska', 'North Carolina', 'Alabama', 'Tennessee', 'Wyoming', 'Mississippi', 'Ohio', 'Utah'}

# %%
#13 states are 100% participate 
oklahoma, wisconsin, kentucky, nevada, montana, louisiana, arkansas, north carolina, alabama, tennessee, mississippi, utah, wyoming

# %% [markdown]
# ### Do any states show have >50% participation on both tests each year?

# %% [markdown]
# ### The following states have more than 50% participation on both tests each year are
#     -2017: Florida, Georgia, Hawaii
#     -2018: Florida, Heorgia, Hawaii, North Carolina, South Carolina
#     -2019: Florida, Hawaii, North Carolina, South Carolina
#
# ### The following states have more than 50% participation on both tests from 2017 to 2019 are
#     -2017 to 2019: Florida & Hawaii

# %%
mask_sat_part_above_50 = Final_sat_act_2017_to_2019[['sat_participation_17', 'sat_participation_18', 'sat_participation_19']] > 0.5
mask_act_part_above_50 = Final_sat_act_2017_to_2019[['act_participation_17', 'act_participation_18', 'act_participation_19']] > 0.5

# %%
sat_act_above_50_2017 = (Final_sat_act_2017_to_2019['sat_participation_17'] > 0.5) & (Final_sat_act_2017_to_2019['act_participation_17'] > 0.5)
Final_sat_act_2017_to_2019[sat_act_above_50_2017]
# Out:
#       state  sat_participation_17  sat_reading_and_writing_17  sat_math_17  \
# 9   Florida                  0.83                         520          497
# 10  Georgia                  0.61                         535          515
# 11   Hawaii                  0.55                         544          541
#
#     sat_total_17  act_participation_17  act_english_17  act_math_17  \
# 9           1017                  0.73            19.0         19.4
# 10          1050                  0.55            21.0         20.9
# 11          1085                  0.90            17.8         19.2
#
#     act_reading_17  act_science_17  ...  sat_participation_19  \
# 9             21.0            19.4  ...                  1.00
# 10            22.0            21.3  ...                  0.71
# 11            19.2            19.3  ...                  0.54
#
#     sat_reading_and_writing_19  sat_math_19  sat_total_19  \
# 9                          516          483           999
# ...

# %%
sat_act_above_50_2018 = (Final_sat_act_2017_to_2019['sat_participation_18'] > 0.5) & (Final_sat_act_2017_to_2019['act_participation_18'] > 0.5)
Final_sat_act_2017_to_2019[sat_act_above_50_2018]
# Out:
#              state  sat_participation_17  sat_reading_and_writing_17  \
# 9          Florida                  0.83                         520
# 10         Georgia                  0.61                         535
# 11          Hawaii                  0.55                         544
# 33  North Carolina                  0.49                         546
# 40  South Carolina                  0.50                         543
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 9           497          1017                  0.73            19.0
# 10          515          1050                  0.55            21.0
# 11          541          1085                  0.90            17.8
# 33          535          1081                  1.00            17.8
# 40          521          1064                  1.00            17.5
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# ...

# %%
sat_act_above_50_2019 = (Final_sat_act_2017_to_2019['sat_participation_19'] > 0.5) & (Final_sat_act_2017_to_2019['act_participation_19'] > 0.5)
Final_sat_act_2017_to_2019[sat_act_above_50_2019]
# Out:
#              state  sat_participation_17  sat_reading_and_writing_17  \
# 9          Florida                  0.83                         520
# 11          Hawaii                  0.55                         544
# 33  North Carolina                  0.49                         546
# 40  South Carolina                  0.50                         543
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 9           497          1017                  0.73            19.0
# 11          541          1085                  0.90            17.8
# 33          535          1081                  1.00            17.8
# 40          521          1064                  1.00            17.5
#
#     act_math_17  act_reading_17  act_science_17  ...  sat_participation_19  \
# 9          19.4            21.0            19.4  ...                  1.00
# 11         19.2            19.2            19.3  ...                  0.54
# ...

# %%
Final_sat_act_2017_to_2019[(sat_act_above_50_2017) & (sat_act_above_50_2018) & (sat_act_above_50_2019)]
# Out:
#       state  sat_participation_17  sat_reading_and_writing_17  sat_math_17  \
# 9   Florida                  0.83                         520          497
# 11   Hawaii                  0.55                         544          541
#
#     sat_total_17  act_participation_17  act_english_17  act_math_17  \
# 9           1017                  0.73            19.0         19.4
# 11          1085                  0.90            17.8         19.2
#
#     act_reading_17  act_science_17  ...  sat_participation_19  \
# 9             21.0            19.4  ...                  1.00
# 11            19.2            19.3  ...                  0.54
#
#     sat_reading_and_writing_19  sat_math_19  sat_total_19  \
# 9                          516          483           999
# 11                         550          550          1100
#
#     act_participation_19  act_english_19  act_math_19  act_reading_19  \
# 9                   0.54            19.5         19.5            21.2
# ...

# %%
#Checking 'Florida' state that has participation rate above 50% from 2017 - 2019 both on SAT and ACT Test
print(Final_sat_act_2017_to_2019['sat_participation_17'][9])
print(Final_sat_act_2017_to_2019['sat_participation_18'][9])
print(Final_sat_act_2017_to_2019['sat_participation_19'][9])

print(Final_sat_act_2017_to_2019['act_participation_17'][9])
print(Final_sat_act_2017_to_2019['act_participation_18'][9])
print(Final_sat_act_2017_to_2019['act_participation_19'][9])
# Out:
# 0.83
# 0.56
# 1.0
# 0.73
# 0.66
# 0.54

# %%
#Checking 'Hawaii' state that has participation rate above 50% from 2017 - 2019 both on SAT and ACT Test
print(Final_sat_act_2017_to_2019['sat_participation_17'][11])
print(Final_sat_act_2017_to_2019['sat_participation_18'][11])
print(Final_sat_act_2017_to_2019['sat_participation_19'][11])

print(Final_sat_act_2017_to_2019['act_participation_17'][11])
print(Final_sat_act_2017_to_2019['act_participation_18'][11])
print(Final_sat_act_2017_to_2019['act_participation_19'][11])
# Out:
# 0.55
# 0.56
# 0.54
# 0.9
# 0.89
# 0.8

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
plt.figure(figsize=(20, 20));
plt.title('Correlation of all data from SAT and ACT 2017-2019', size=16);
sns.heatmap(Final_sat_act_2017_to_2019.corr(), annot = True, cmap = 'YlGnBu');

# %%
mask = np.zeros_like(Final_sat_act_2017_to_2019.corr())
mask[np.triu_indices_from(mask)] = True;
plt.figure(figsize=(20, 20));
plt.title('Correlation of all data from SAT and ACT 2017-2019', size=16);
sns.heatmap(Final_sat_act_2017_to_2019.corr(), mask = mask, annot = True);

# %%
#create function for a subplot of histograms 
def subplot_histograms(dataframe, list_of_columns, list_of_titles, ylabel, xlabel, figtitle):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(10, 10))  
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    
    
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        ax[i].set_ylabel(ylabel, fontsize = 10)
        ax[i].set_xlabel(xlabel, fontsize = 10)
        
    for i, title in enumerate(list_of_titles):
        ax[i].set_title(title, fontsize=12)
        
    fig.suptitle(figtitle, size=16) 
    plt.tight_layout()
    fig.subplots_adjust(top=.91)

# %%
# Create variables to intput into histogram function for creating SAT & ACT Total/Composite Scores in 2017 - 2019

final_col = list(Final_sat_act_2017_to_2019.columns)
final_col = ['sat_total_19','act_composite_19','sat_total_18','act_composite_18', 'sat_total_17','act_composite_17']
titles = ['SAT 2019 Total Scores', 'ACT 2019 Composite Scores','SAT 2018 Total Scores', 'ACT 2018 Composite Scores', 'SAT 2017 Total Scores', 'ACT 2017 Composite Scores']

# %%
# Visualize SAT & ACT Total/Composite Scores in 2017 - 2019
subplot_histograms(Final_sat_act_2017_to_2019, 
                   final_col, 
                   titles, 
                   "# of States", "Range of Scores", 'SAT & ACT Total/Composite Scores in 2017-19')

# %%
# Create variables to intput into histogram function for creating SAT & ACT Participation Rates  in 2017 - 2019

participation_col = ['sat_participation_19', 'act_participation_19','sat_participation_18', 'act_participation_18', 'sat_participation_17', 'act_participation_17']
participation_titles = ['SAT 2019 Participation %', 'ACT 2019 Participation %','SAT 2018 Participation %', 'ACT 2018 Participation %', 'SAT 2017 Participation %', 'ACT 2017 Participation %']

# Visualize SAT & ACT Participation Rates in 2017 - 2019
subplot_histograms(Final_sat_act_2017_to_2019, participation_col, participation_titles, "# of States", "Participation Rates (%)", 'SAT & ACT Participation Rates in 2017-2019')

# %% [markdown]
# For the SAT, there are less states that have 100% participation rate, and even more states that have a lower participation rate. The opposite is true for the ACT.

# %%
# Create variables to intput into histogram function for creating SAT & ACT Math scores  in 2017 - 2019

math_scores_col = ['sat_math_19','sat_math_18', 'sat_math_17', 'act_math_19','act_math_18','act_math_17']
math_titles = ['SAT 2019 Math Scores', 'SAT 2018 Math Scores', 'SAT 2017 Math Scores', 'ACT 2019 Math Scores', 'ACT 2018 Math Scores', 'ACT 2017 Math Scores']

subplot_histograms(Final_sat_act_2017_to_2019, math_scores_col, math_titles, "# of States", "Range of Math Scores", 'SAT & ACT Math Scores in 2017-19')

# %%
# A function to create a subplot of scatterplots 
def subplot_scatter(dataframe, list_of_columns1, list_of_columns2, list_of_titles, ylabel, xlabel, figtitle):
    nrows = int(np.ceil(len(list_of_columns1)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(18, 20))  
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate  
    
    for i, (column1, column2) in enumerate(zip(x_axis_scatter, y_axis_scatter)):
        ax[i].scatter(dataframe[column1], dataframe[column2]) 
        ax[i].set_xlabel(xlabel[i])
        ax[i].set_ylabel(ylabel[i])
        
    for i, title in enumerate(list_of_titles):
        ax[i].set_title(title, fontsize=12)
    fig.suptitle(figtitle, size=16) 
    plt.tight_layout()
    fig.subplots_adjust(top=.93)

# %%
# Creat variables to input into the `subplot_scatter` function

x_axis_scatter = ['act_participation_19','act_participation_18','act_participation_17','sat_participation_19', 'sat_participation_18','sat_participation_17', 'sat_math_19', 'sat_reading_and_writing_19', 'sat_total_19', 'sat_math_18', 'sat_reading_and_writing_18', 'sat_total_18',
'sat_math_17', 'sat_reading_and_writing_17', 'sat_total_17', 'sat_total_19', 'sat_total_18', 'act_composite_19', 'act_composite_18']

y_axis_scatter = ['act_composite_19','act_composite_18','act_composite_17', 'sat_total_19', 'sat_total_18','sat_total_17','act_math_19', 'act_english_19', 'act_composite_19', 'act_math_18', 'act_english_18', 'act_composite_18', 'act_math_17', 'act_english_17', 'act_composite_17', 'sat_total_18', 'sat_total_17', 'act_composite_18', 'act_composite_17']

scatter_titles = ['ACT Participation Rates vs Composite Scores in 2019','ACT Participation Rates vs Composite Scores in 2018', 'ACT Participation Rates vs Composite Scores in 2017','SAT Participation Rates vs Total Scores in 2019','SAT Participation Rates vs Total Scores in 2018','SAT Participation Rates vs Total Scores in 2017', 'SAT vs. ACT math scores for 2019', 'SAT vs. ACT verbal/reading scores for 2019', 'SAT vs. ACT total/composite scores for 2019',
'SAT vs. ACT math scores for 2018', 'SAT vs. ACT verbal/reading scores for 2018', 'SAT vs. ACT total/composite scores for 2018', 'SAT vs. ACT math scores for 2017', 'SAT vs. ACT verbal/reading scores for 2017', 'SAT vs. ACT total/composite scores for 2017', 'Total scores for SAT 2019 vs. 2018', 'Total scores for SAT 2018 vs. 2017', 'Composite scores for ACT 2019 vs. 2018', 'Composite scores for ACT 2018 vs. 2017' ]

x_axis_labels = ['Participation Rates (0%-100%)','Participation Rates (0%-100%)','Participation Rates (0%-100%)','Participation Rates (0%-100%)', 'Participation Rates (0%-100%)', 'Participation Rates (0%-100%)', 'SAT Math 2019', 'SAT Reading and Writing 2019', 'SAT Total 2019', 'SAT Math 2018', 'SAT Reading and Writing 2018', 'SAT Total 2018', 'SAT Math 2017', 'SAT Reading and Writing 2017', 'SAT Total 2017', 'SAT Total 2019', 'SAT Total 2018', 'ACT Composite 2019', 'ACT Composite 2018']

y_axis_slabels = ['Composite Scores (1-36)','Composite Scores (1-36)', 'Composite Scores (1-36)','Total Scores (400-600)','Total Scores (400-600)', 'Total Scores (400-600)', 'ACT Math 2019', 'ACT English 2019', 'ACT Composite 2019', 'ACT Math 2018', 'ACT English 2018', 'ACT Composite 2018', 'ACT Math 2017', 'ACT English 2017', 'ACT Composite 2017', 'SAT Total 2018', 'SAT Total 2017', 'ACT Composite 2018', 'ACT Composite 2017']

# %%
# Visualize ACT & SAT Correlation for All Data
subplot_scatter(Final_sat_act_2017_to_2019, x_axis_scatter, y_axis_scatter, scatter_titles, y_axis_slabels, x_axis_labels, 'SAT & ACT Correlation for All Data')

# %%
def create_scatterplot(title,x,y,xlabel=None,ylabel=None,regplot=False,lineplot=False):
    
    if xlabel == None:
        xlabel = x.name
    if ylabel == None:
        ylabel = y.name
        
    plt.figure(figsize=(8,8))
        
    if regplot:
        sns.regplot(x=x,y=y)
    else:
        sns.scatterplot(x=x,y=y)
        
    if lineplot == True:    
        
        diff_x = max(x) - min(x)        
        if diff_x > 36:
            sf = 50
        else:
            sf = 1   
        
        min_x = np.floor((min(x)*0.95)/sf) * sf
        max_x = np.ceil((max(x)*1.05)/sf) * sf      
        
        X_plot = np.linspace(min_x, max_x, 100)
        Y_plot = X_plot    
        plt.plot(X_plot, Y_plot, color='salmon',linestyle='dashed')
        plt.xlim(min_x,max_x)
        plt.ylim(min_x,max_x)
                    
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
#Total scores for SAT 2017 vs. 2018

x = Final_sat_act_2017_to_2019['sat_total_17']
y = Final_sat_act_2017_to_2019['sat_total_18']
title = ("Total scores for SAT 2017 vs 2018")
         
create_scatterplot(title,x,y,2017,2018,lineplot=True)
print('Note: States in top triangle (seperated by red line) performed better in 2017.')
# Out:
# Note: States in top triangle (seperated by red line) performed better in 2017.

# %%
#Total scores for SAT 2018 vs. Act composite 2018

x = Final_sat_act_2017_to_2019['sat_total_18']
y = Final_sat_act_2017_to_2019['act_composite_18']
title = ("Sat Total 2018 vs Act composite 2018")
         
create_scatterplot(title,x,y,2018,2018)
print('Note: States in top triangle (seperated by red line) performed better in 2017.')
# Out:
# Note: States in top triangle (seperated by red line) performed better in 2017.

# %%
#SAT vs. ACT participation for 2019

x = Final_sat_act_2017_to_2019['sat_participation_19']
y = Final_sat_act_2017_to_2019['act_participation_19']
title = ("SAT vs. ACT participation for 2019")
         
create_scatterplot(title,x,y,regplot=True)

# %%
# A function to create a subplot of comparative boxplots 

def subplot_boxplot(dataframe, box_1, box_2, list_of_titles, box_1_titles, box_2_titles, figtitle):
    nrows = int(np.ceil(len(box_1)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(15, 18))  
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate  
    
    for i, (boxplot_1, boxplot_2) in enumerate(zip(box_1, box_2)):
        ax[i].boxplot([dataframe[boxplot_1],dataframe[boxplot_2]], widths=.7, labels = [box_1_titles[i], box_2_titles[i]] ) 
        for i, title in enumerate(list_of_titles):
             ax[i].set_title(title, fontsize=12)
    fig.suptitle(figtitle, size=16) 
    plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
    fig.subplots_adjust(top=.93)

# %%
# Create variables to input into boxplot function 

box_1_list = ['act_composite_19', 'sat_total_19', 'act_participation_19', 'sat_participation_19', 'sat_math_19', 'sat_reading_and_writing_19' ]
box_2_list = ['act_composite_18', 'sat_total_18', 'act_participation_18', 'sat_participation_18', 'sat_math_18', 'sat_reading_and_writing_18']
box_1_titles = ['ACT Composite 2019', 'SAT Total 2019', 'ACT Participation 2019', 'SAT Participation 2019', 'SAT Math 2019', 'SAT Reading and Writing 2019']
box_2_titles = ['ACT Composite 2018', 'SAT Total 2018', 'ACT Participation 2018', 'SAT Participation 2018', 'SAT Math 2018', 'SAT Reading and Writing 2018']
box_titles = ['ACT Compositive 2019 vs 2018', 'SAT Total 2019 vs 2018', 'ACT Participation 2019 vs 2018', 'SAT Participation 2019 vs 2018', 'SAT Math 2017 vs 2018', 'SAT Reading and Writing 2019 vs 2018']

# %%
# Boxplot Comparisons for SAT & ACT 2018-19 Scores & Participation Rates 

subplot_boxplot(Final_sat_act_2017_to_2019, box_1_list, box_2_list, box_titles, box_1_titles, box_2_titles, 'Boxplot Comparisons for SAT & ACT 2018-19 Scores & Participation Rates')

# %%
# Create variables to input into boxplot function 

box_3_list = ['act_composite_18', 'sat_total_18', 'act_participation_18', 'sat_participation_18', 'sat_math_18', 'sat_reading_and_writing_18' ]
box_4_list = ['act_composite_17', 'sat_total_17', 'act_participation_17', 'sat_participation_17', 'sat_math_17', 'sat_reading_and_writing_17']
box_3_titles = ['ACT Composite 2018', 'SAT Total 2018', 'ACT Participation 2018', 'SAT Participation 2018', 'SAT Math 2018', 'SAT Reading and Writing 2018']
box_4_titles = ['ACT Composite 2017', 'SAT Total 2017', 'ACT Participation 2017', 'SAT Participation 2017', 'SAT Math 2017', 'SAT Reading and Writing 2017']
box_titles = ['ACT Compositive 2018 vs 2017', 'SAT Total 2018 vs 2017', 'ACT Participation 2018 vs 2017', 'SAT Participation 2018 vs 2017', 'SAT Math 2018 vs 2017', 'SAT Reading and Writing 2018 vs 2017']

# %%
# Boxplot Comparisons for SAT & ACT 2017-18 Scores & Participation Rates 

subplot_boxplot(Final_sat_act_2017_to_2019, box_3_list, box_4_list, box_titles, box_3_titles, box_4_titles, 'Boxplot Comparisons for SAT & ACT 2017-18 Scores & Participation Rates')

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# Based on the data on hand and analysis, I find out that the opportunity of students who prefer taking SAT test is getting higher and there's still a room for growth in the future. Thus, I will recommend marketing to spend more time and budget for creating campaign for attracting students who want scholarship in the low participation states i.e.; South Dakota, Wyoming, Lowa, Mississippi, and North Dakota.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
